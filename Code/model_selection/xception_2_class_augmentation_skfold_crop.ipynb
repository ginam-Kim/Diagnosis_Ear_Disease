# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Library

# %%
import os
import random
from collections import defaultdict
import numpy as np
import shutil
import matplotlib.pyplot as plt
import cv2
import imageio.v2 as iio  # Import imageio.v2 instead of imageio
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# %%
from keras.layers import *
from keras.callbacks import *
from keras.optimizers import *

# %% [markdown]
# # 1. Data Preprocessing

# %% [markdown]
# ## 1) 데이터 수 확인

# %%
import pandas as pd
import os

directory_path = '/content/drive/MyDrive/eardrum2/crop_data/train/'
folders = ['Normal', 'Abnormal']

# 이미지 파일과 레이블을 저장하기 위한 리스트
image_paths = []
labels = []

# 각 폴더(레이블)에 대해 반복
for folder in folders:
  folder_path = os.path.join(directory_path, folder)
  # 해당 폴더 내의 모든 파일에 대해 반복
  for filename in os.listdir(folder_path):
    # 파일 경로와 레이블을 리스트에 추가
    image_paths.append(os.path.join(folder_path, filename))
    labels.append(folder)

# DataFrame 생성
df = pd.DataFrame({
    'image_path': image_paths,
    'label': labels
})

# 데이터 확인
print(df.head())
# Out:
#                                           image_path   label
# 0  /content/drive/MyDrive/eardrum2/crop_data/trai...  Normal
# 1  /content/drive/MyDrive/eardrum2/crop_data/trai...  Normal
# 2  /content/drive/MyDrive/eardrum2/crop_data/trai...  Normal
# 3  /content/drive/MyDrive/eardrum2/crop_data/trai...  Normal
# 4  /content/drive/MyDrive/eardrum2/crop_data/trai...  Normal

# %% [markdown]
# - 파일 format 확인

# %%
def unique_file_formats_in_directory(directory_path):
    file_formats = {os.path.splitext(f)[1].lower() for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))}
    return file_formats

for folder in folders:
    path = directory_path + folder
    unique_formats = unique_file_formats_in_directory(path)
    print(folder, ":", unique_formats)
# Out:
# Normal : {'.png'}
# Abnormal : {'.png'}

# %% [markdown]
# ## 2) 데이터 분할 -> ※ 다시 실행 하지 말것!!!

# %%
import os
import random
from collections import defaultdict

# Define the categories and their corresponding image counts
categories = {
    "Normal": 534,
    "AOM": 119,
    "CSOM": 63,
    "Earwax": 140,
    "OE": 41,
    "Tympanoskleros": 28
}

# Define the desired proportions for train, validation, and test sets
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Calculate the total number of images in the dataset
total_images = sum(categories.values())
print(total_images)
# Out:
# 925

# %%
import os
import numpy as np
import shutil

# Defining your directories
base_dir = '/content/drive/MyDrive/eardrum/data/'
base_dirs = [os.path.join(base_dir, d) for d in os.listdir(base_dir)]

train_dir = '/content/drive/MyDrive/eardrum/new_data/train'
val_dir = '/content/drive/MyDrive/eardrum/new_data/val'
test_dir = '/content/drive/MyDrive/eardrum/new_data/test'

# %%
base_dirs
# Out:
# ['/content/drive/MyDrive/eardrum/data/Earwax',
#  '/content/drive/MyDrive/eardrum/data/Normal',
#  '/content/drive/MyDrive/eardrum/data/CSOM',
#  '/content/drive/MyDrive/eardrum/data/AOM',
#  '/content/drive/MyDrive/eardrum/data/OE',
#  '/content/drive/MyDrive/eardrum/data/Tympanoskleros']

# %%
# Ratio of splitting
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Iterate over all directories (classes) in your base directory
for dir_path in base_dirs: # -> 1분 40초 소요
    class_name = os.path.basename(dir_path)

    # Create corresponding directories in train, val, test directories
    os.makedirs(os.path.join(train_dir, class_name), exist_ok=True)
    os.makedirs(os.path.join(val_dir, class_name), exist_ok=True)
    os.makedirs(os.path.join(test_dir, class_name), exist_ok=True)

    # Get all file names and shuffle them
    files = os.listdir(dir_path)
    np.random.shuffle(files)

    # Calculate split indices
    train_idx = int(len(files) * train_ratio)
    val_idx = int(len(files) * (train_ratio + val_ratio))

    # Split file names
    train_files = files[:train_idx]
    val_files = files[train_idx:val_idx]
    test_files = files[val_idx:]

    # Move files to corresponding directories
    for file_name in train_files:
        shutil.copy(os.path.join(dir_path, file_name), os.path.join(train_dir, class_name, file_name))

    for file_name in val_files:
        shutil.copy(os.path.join(dir_path, file_name), os.path.join(val_dir, class_name, file_name))

    for file_name in test_files:
        shutil.copy(os.path.join(dir_path, file_name), os.path.join(test_dir, class_name, file_name))

# %%
new_data_path = '/content/drive/MyDrive/eardrum/new_data/'

folders = ['Normal', 'AOM', 'CSOM', 'Earwax', 'OE', 'Tympanoskleros']

print("Train Set:")
for folder in folders:
  path = new_data_path + 'train/'+folder
  print(folder, ':', count_files_in_directory(path))

print("\nVal Set:")
for folder in folders:
  path = new_data_path + 'val/'+folder
  print(folder, ':', count_files_in_directory(path))

print("\nTest Set:")
for folder in folders:
  path = new_data_path + 'test/'+folder
  print(folder, ':', count_files_in_directory(path))
# Out:
# Train Set:
# Normal : 373
# AOM : 83
# CSOM : 44
# Earwax : 98
# OE : 28
# Tympanoskleros : 19
#
# Val Set:
# Normal : 80
# AOM : 18
# CSOM : 9
# Earwax : 21
# OE : 6
# Tympanoskleros : 4
#
# Test Set:
# Normal : 81
# AOM : 18
# CSOM : 10
# Earwax : 21
# OE : 7
# Tympanoskleros : 5

# %% [markdown]
# ## 3) ImageDataGenerator

# %% [markdown]
# - 임의로 뽑아서 시각화

# %%
train_dir = '/content/drive/MyDrive/eardrum2/crop_data/train'
test_dir = '/content/drive/MyDrive/eardrum2/crop_data/test'

# %%
import matplotlib.pyplot as plt
import cv2
import imageio.v2 as iio  # Import imageio.v2 instead of imageio

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Load the TIFF image using imageio.v2
img = iio.imread(train_dir + '/Normal/normal_1.png')
axes[0].imshow(img)

img = iio.imread(train_dir + '/Normal/normal_2.png')
axes[1].imshow(img)

plt.show()

# %%
img.shape
# Out:
# (400, 400, 3)

# %% [markdown]
# - image shape : (500, 500, 3)

# %%
from keras.preprocessing.image import ImageDataGenerator

# 고막 내시경에 적합한 데이터 증강 방법 적용 -> 수정할 것
train_datagen = ImageDataGenerator(
                                  rotation_range=40,           # 랜덤하게 이미지 회전 각도 설정 (0~40도 사이)
                                  horizontal_flip=True,          # 수평 방향으로 랜덤하게 이미지 뒤집기
                                  vertical_flip=True,            # 수직 방향으로 랜덤하게 이미지 뒤집기
                                  zoom_range=(0.8, 1),           # 랜덤하게 확대/축소 범위 설정, 0.7: 확대, 1: 원본크기와 동일
                                  brightness_range=[0.7, 1.3],  # 명도 범위
                                  rescale = 1/255.0)

test_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# - image size 수정? -> (448, 448)
# - batch size 수정? -> 16? 8?

# %%
from sklearn.model_selection import StratifiedKFold
# 데이터 생성기 설정
datagen = ImageDataGenerator(rescale=1./255)

# StratifiedKFold 객체를 생성한다
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# - 데이터 증강된 이미지 확인해보기

# %% [markdown]
# # 2. Model

# %%
SHAPE = (299, 299, 3)
BATCH_SIZE = 16
EPOCHS = 40
TOTAL_CLASS_NUMBER = 2 # 2, 3

# %%
from keras import backend as K

# %%
class SGDRScheduler(Callback):
    def __init__(self,
                 min_lr,
                 max_lr,
                 steps_per_epoch,
                 lr_decay=1,
                 cycle_length=10,
                 mult_factor=2):

        self.min_lr = min_lr
        self.max_lr = max_lr
        self.lr_decay = lr_decay

        self.batch_since_restart = 0
        self.next_restart = cycle_length

        self.steps_per_epoch = steps_per_epoch

        self.cycle_length = cycle_length
        self.mult_factor = mult_factor

        self.history = {}

    def clr(self):
        '''Calculate the learning rate.'''
        fraction_to_restart = self.batch_since_restart / (self.steps_per_epoch * self.cycle_length)
        lr = self.min_lr + 0.5 * (self.max_lr - self.min_lr) * (1 + np.cos(fraction_to_restart * np.pi))
        return lr

    def on_train_begin(self, logs={}):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.max_lr)

    def on_batch_end(self, batch, logs={}):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

        self.batch_since_restart += 1
        K.set_value(self.model.optimizer.lr, self.clr())

    def on_epoch_end(self, epoch, logs={}):
        '''Check for end of current cycle, apply restarts when necessary.'''
        if epoch + 1 == self.next_restart:
            self.batch_since_restart = 0
            self.cycle_length = np.ceil(self.cycle_length * self.mult_factor)
            self.next_restart += self.cycle_length
            self.max_lr *= self.lr_decay
            self.best_weights = self.model.get_weights()

    def on_train_end(self, logs={}):
        '''Set weights to the values from the end of the most recent cycle for best performance.'''
        self.model.set_weights(self.best_weights)

# %%
# credits: https://stackoverflow.com/questions/43547402/how-to-calculate-f1-macro-in-keras
def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1(y_true, y_pred):
    precisionx = precision(y_true, y_pred)
    recallx = recall(y_true, y_pred)
    return 2*((precisionx*recallx)/(precisionx+recallx+K.epsilon()))

# %% [markdown]
# - ReduceLROnPlateau:
#   - 검증 손실(val_loss)이 10번의 에포크(patience)동안 향상되지 않으면 학습률(learning rate)을 0.1배(factor)로 감소시킵니다.
#   - 이는 학습 도중 학습률을 동적으로 조절하여 학습을 안정화시키는 데 사용됩니다.
# - EarlyStopping:
#   - 검증 손실(val_loss)이 20번의 에포크(patience)동안 향상되지 않으면 학습을 조기에 종료합니다.
#   - 이를 통해 과적합을 방지하고 효율적인 학습을 할 수 있습니다.
# - ModelCheckpoint:
#   - 검증 손실(val_loss)이 가장 낮을 때 모델을 저장합니다.
#   - 이를 통해 최상의 성능을 보이는 모델을 저장하여 나중에 재사용할 수 있습니다.

# %%
# 활성 세션 내 모델 저장소 디렉토리 생성
os.makedirs('/content/model/')

# %%
schedule = SGDRScheduler(min_lr=1e-6,
                         max_lr=1e-3,
                         steps_per_epoch=np.ceil(EPOCHS/BATCH_SIZE),
                         lr_decay=0.9,
                         cycle_length=10,
                         mult_factor=2.)

# %%
# ModelCheckpoint 콜백 설정
fold_var = 1
model_checkpoint_callback = ModelCheckpoint(
    filepath=f'model_fold_{fold_var}.h5',  # 파일 경로 및 이름
    save_best_only=True,  # True면 모델의 정확도가 개선되었을 때만 저장
    monitor='val_loss',  # 'val_loss'를 모니터링하여 개선될 때 저장
    mode='min',  # 'min' 모드는 'val_loss'가 감소할 때 모델을 저장
    verbose=1  # 1로 설정하면 언제 모델을 저장하는지 출력
)

# %%
X = df['image_path'].values  # 이미지 경로
y = df['label'].values  # 레이블

# %%
import tensorflow as tf
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.models import Model

# %%
for train_index, val_index in kf.split(X, y):
    training_data = df.iloc[train_index]
    validation_data = df.iloc[val_index]

    train_generator = train_datagen.flow_from_dataframe(
        dataframe=training_data,
        directory=None,
        x_col="image_path",
        y_col="label",
        target_size=(299, 299),
        class_mode='categorical',
        batch_size=16,
        shuffle=True,
        seed=42)

    validation_generator = test_datagen.flow_from_dataframe(
        dataframe=validation_data,
        directory=None,
        x_col="image_path",
        y_col="label",
        target_size=(299, 299),
        class_mode='categorical',
        batch_size=16,
        shuffle=True,
        seed=42)

    xception_model = Xception(weights = 'imagenet',
                          include_top = False,
                          input_shape = (299, 299, 3))

    x = GlobalAveragePooling2D()(xception_model.output)
    x = Dense(256, activation = 'relu')(x)
    x = Dense(2, activation = 'softmax')(x)  # Modify the final Dense layer based on your specific problem

    model = Model(inputs = xception_model.input, outputs = x)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=[precision, recall, f1, 'acc'])


    history = model.fit(
        train_generator,
        validation_data=validation_generator,
        epochs=40,  # 실제 상황에 맞게 조정할 것
        verbose=1,
        callbacks=[model_checkpoint_callback, schedule])

    # 필요하다면 모델 저장
    model.save(f'model_fold_{fold_var}.h5')
    fold_var += 1
# Out:
# Found 470 validated image filenames belonging to 2 classes.
# Found 118 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step
# Epoch 1/40
# 30/30 [==============================] - ETA: 0s - loss: 0.5109 - precision: 0.7507 - recall: 0.7507 - f1: 0.7507 - acc: 0.7489
# Epoch 1: val_loss improved from inf to 1.79648, saving model to model_fold_1.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 30/30 [==============================] - 333s 10s/step - loss: 0.5109 - precision: 0.7507 - recall: 0.7507 - f1: 0.7507 - acc: 0.7489 - val_loss: 1.7965 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7712
# Epoch 2/40
# 30/30 [==============================] - ETA: 0s - loss: 0.4235 - precision: 0.7639 - recall: 0.7639 - f1: 0.7639 - acc: 0.7660
# Epoch 2: val_loss improved from 1.79648 to 0.51886, saving model to model_fold_1.h5
# 30/30 [==============================] - 17s 589ms/step - loss: 0.4235 - precision: 0.7639 - recall: 0.7639 - f1: 0.7639 - acc: 0.7660 - val_loss: 0.5189 - val_precision: 0.7969 - val_recall: 0.7969 - val_f1: 0.7969 - val_acc: 0.7797
# Epoch 3/40
# 30/30 [==============================] - ETA: 0s - loss: 0.4091 - precision: 0.8382 - recall: 0.8382 - f1: 0.8382 - acc: 0.8383
# Epoch 3: val_loss improved from 0.51886 to 0.49354, saving model to model_fold_1.h5
# 30/30 [==============================] - 18s 569ms/step - loss: 0.4091 - precision: 0.8382 - recall: 0.8382 - f1: 0.8382 - acc: 0.8383 - val_loss: 0.4935 - val_precision: 0.7708 - val_recall: 0.7708 - val_f1: 0.7708 - val_acc: 0.7797
# Epoch 4/40
# 30/30 [==============================] - ETA: 0s - loss: 0.3515 - precision: 0.8507 - recall: 0.8507 - f1: 0.8507 - acc: 0.8511
# Epoch 4: val_loss did not improve from 0.49354
# 30/30 [==============================] - 17s 553ms/step - loss: 0.3515 - precision: 0.8507 - recall: 0.8507 - f1: 0.8507 - acc: 0.8511 - val_loss: 1.3339 - val_precision: 0.7708 - val_recall: 0.7708 - val_f1: 0.7708 - val_acc: 0.7797
# Epoch 5/40
# 30/30 [==============================] - ETA: 0s - loss: 0.3482 - precision: 0.8521 - recall: 0.8521 - f1: 0.8521 - acc: 0.8489
# Epoch 5: val_loss did not improve from 0.49354
# 30/30 [==============================] - 16s 533ms/step - loss: 0.3482 - precision: 0.8521 - recall: 0.8521 - f1: 0.8521 - acc: 0.8489 - val_loss: 0.5080 - val_precision: 0.7786 - val_recall: 0.7786 - val_f1: 0.7786 - val_acc: 0.7881
# Epoch 6/40
# 30/30 [==============================] - ETA: 0s - loss: 0.
val_loss did not improve from 0.37911
# 30/30 [==============================] - 17s 543ms/step - loss: 0.3659 - precision: 0.8375 - recall: 0.8375 - f1: 0.8375 - acc: 0.8340 - val_loss: 0.4665 - val_precision: 0.7839 - val_recall: 0.7839 - val_f1: 0.7839 - val_acc: 0.7797
# Epoch 4/40
# 30/30 [==============================] - ETA: 0s - loss: 0.3657 - precision: 0.8493 - recall: 0.8493 - f1: 0.8493 - acc: 0.8532
# Epoch 4: val_loss did not improve from 0.37911
# 30/30 [==============================] - 17s 549ms/step - loss: 0.3657 - precision: 0.8493 - recall: 0.8493 - f1: 0.8493 - acc: 0.8532 - val_loss: 0.3879 - val_precision: 0.7708 - val_recall: 0.7708 - val_f1: 0.7708 - val_acc: 0.7797
# Epoch 5/40
# 30/30 [==============================] - ETA: 0s - loss: 0.3648 - precision: 0.8417 - recall: 0.8417 - f1: 0.8417 - acc: 0.8383
# Epoch 5: val_loss improved from 0.37911 to 0.35934, saving model to model_fold_1.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 30/30 [==============================] - 17s 572ms/step - loss: 0.3648 - precision: 0.8417 - recall: 0.8417 - f1: 0.8417 - acc: 0.8383 - val_loss: 0.3593 - val_precision: 0.8828 - val_recall: 0.8828 - val_f1: 0.8828 - val_acc: 0.8729
# Epoch 6/40
# 30/30 [==============================] - ETA: 0s - loss: 0.4388 - precision: 0.7757 - recall: 0.7757 - f1: 0.7757 - acc: 0.7745
# Epoch 6: val_loss did not improve from 0.35934
# 30/30 [==============================] - 17s 547ms/step - loss: 0.4388 - precision: 0.7757 - recall: 0.7757 - f1: 0.7757 - acc: 0.7745 - val_loss: 2.3249 - val_precision: 0.7786 - val_recall: 0.7786 - val_f1: 0.7786 - val_acc: 0.7881
# Epoch 7/40
# 30/30 [==============================] - ETA: 0s - loss: 0.4134 - precision: 0.8438 - recall: 0.8438 - f1: 0.8437 - acc: 0.8404
# Epoch 7: val_loss did not improve from 0.35934
# 30/30 [==============================] - 16s 545ms/step - loss: 0.4134 - precision: 0.8438 - recall: 0.8438 - f1: 0.8437 - acc: 0.8404 - val_loss: 0.4796 - val_precision: 0.7240 - val_recall: 0.7240 - val_f1: 0.7240 - val_acc: 0.7288
# Epoch 8/40
# 30/30 [==============================] - ETA: 0s - loss: 0.3404 - precision: 0.8674 - recall: 0.8674 - f1: 0.8674 - acc: 0.8681
# Epoch 8: val_loss did not improve from 0.35934
# 30/30 [==============================] - 16s 537ms/step - loss: 0.3404 - precision: 0.8674 - recall: 0.8674 - f1: 0.8674 - acc: 0.8681 - val_loss: 1.4591 - val_precision: 0.5729 - val_recall: 0.5729 - val_f1: 0.5729 - val_acc: 0.5932
# Epoch 9/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2786 - precision: 0.8861 - recall: 0.8861 - f1: 0.8861 - acc: 0.8872
# Epoch 9: val_loss did not improve from 0.35934
# 30/30 [==============================] - 16s 535ms/step - loss: 0.2786 - precision: 0.8861 - recall: 0.8861 - f1: 0.8861 - acc: 0.8872 - val_loss: 0.3977 - val_precision: 0.8672 - val_recall: 0.8672 - val_f1: 0.8672 - val_acc: 0.8559
# Epoch 10/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2543 - precision: 0.8944 - recall: 0.8944 - f1: 0.8944 - acc: 0.8957
# Epoch 10: val_loss improved from 0.35934 to 0.31213, saving model to model_fold_1.h5
# 30/30 [==============================] - 17s 563ms/step - loss: 0.2543 - precision: 0.8944 - recall: 0.8944 - f1: 0.8944 - acc: 0.8957 - val_loss: 0.3121 - val_precision: 0.8776 - val_recall: 0.8776 - val_f1: 0.8776 - val_acc: 0.8814
# Epoch 11/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2480 - precision: 0.8986 - recall: 0.8986 - f1: 0.8986 - acc: 0.9000
# Epoch 11: val_loss improved from 0.31213 to 0.28619, saving model to model_fold_1.h5
# 30/30 [==============================] - 17s 575ms/step - loss: 0.2480 - precision: 0.8986 - recall: 0.8986 - f1: 0.8986 - acc: 0.9000 - val_loss: 0.2862 - val_precision: 0.9219 - val_recall: 0.9219 - val_f1: 0.9219 - val_acc: 0.9153
# Epoch 12/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2619 - precision: 0.8965 - recall: 0.8965 - f1: 0.8965 - acc: 0.8979
# Epoch 12: val_loss improved from 0.28619 to 0.25027, saving model to model_fold_1.h5
# 30/30 [==============================] - 18s 571ms/step - loss: 0.2619 - precision: 0.8965 - recall: 0.8965 - f1: 0.8965 - acc: 0.8979 - val_loss: 0.2503 - val_precision: 0.8932 - val_recall: 0.8932 - val_f1: 0.8932 - val_acc: 0.8983
# Epoch 13/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2649 - precision: 0.8840 - recall: 0.8840 - f1: 0.8840 - acc: 0.8851
# Epoch 13: val_loss did not improve from 0.25027
# 30/30 [==============================] - 17s 557ms/step - loss: 0.2649 - precision: 0.8840 - recall: 0.8840 - f1: 0.8840 - acc: 0.8851 - val_loss: 0.4128 - val_precision: 0.8620 - val_recall: 0.8620 - val_f1: 0.8620 - val_acc: 0.8644
# Epoch 14/40
# 30/30 [==============================] - ETA: 0s - loss: 0.3205 - precision: 0.8757 - recall: 0.8757 - f1: 0.8757 - acc: 0.8766
# Epoch 14: val_loss did not improve from 0.25027
# 30/30 [==============================] - 16s 531ms/step - loss: 0.3205 - precision: 0.8757 - recall: 0.8757 - f1: 0.8757 - acc: 0.8766 - val_loss: 0.7647 - val_precision: 0.7839 - val_recall: 0.7839 - val_f1: 0.7839 - val_acc: 0.7797
# Epoch 15/40
# 30/30 [==============================] - ETA: 0s - loss: 0.3093 - precision: 0.8778 - recall: 0.8778 - f1: 0.8778 - acc: 0.8787
# Epoch 15: val_loss did not improve from 0.25027
# 30/30 [==============================] - 15s 489ms/step - loss: 0.3093 - precision: 0.8778 - recall: 0.8778 - f1: 0.8778 - acc: 0.8787 - val_loss: 0.2839 - val_precision: 0.8854 - val_recall: 0.8854 - val_f1: 0.8854 - val_acc: 0.8898
# Epoch 16/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2322 - precision: 0.9097 - recall: 0.9097 - f1: 0.9097 - acc: 0.9149
# Epoch 16: val_loss did not improve from 0.25027
# 30/30 [==============================] - 17s 545ms/step - loss: 0.2322 - precision: 0.9097 - recall: 0.9097 - f1: 0.9097 - acc: 0.9149 - val_loss: 0.5553 - val_precision: 0.8073 - val_recall: 0.8073 - val_f1: 0.8073 - val_acc: 0.8051
# Epoch 17/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2117 - precision: 0.9049 - recall: 0.9049 - f1: 0.9049 - acc: 0.9064
# Epoch 17: val_loss did not improve from 0.25027
# 30/30 [==============================] - 16s 541ms/step - loss: 0.2117 - precision: 0.9049 - recall: 0.9049 - f1: 0.9049 - acc: 0.9064 - val_loss: 0.2675 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8475
# Epoch 18/40
# 30/30 [==============================] - ETA: 0s - loss: 0.
40
# 30/30 [==============================] - ETA: 0s - loss: 0.1359 - precision: 0.9396 - recall: 0.9396 - f1: 0.9396 - acc: 0.9383
# Epoch 28: val_loss improved from 0.24697 to 0.24217, saving model to model_fold_1.h5
# 30/30 [==============================] - 18s 582ms/step - loss: 0.1359 - precision: 0.9396 - recall: 0.9396 - f1: 0.9396 - acc: 0.9383 - val_loss: 0.2422 - val_precision: 0.9141 - val_recall: 0.9141 - val_f1: 0.9141 - val_acc: 0.9068
# Epoch 29/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1773 - precision: 0.9417 - recall: 0.9417 - f1: 0.9417 - acc: 0.9404
# Epoch 29: val_loss did not improve from 0.24217
# 30/30 [==============================] - 17s 564ms/step - loss: 0.1773 - precision: 0.9417 - recall: 0.9417 - f1: 0.9417 - acc: 0.9404 - val_loss: 0.2679 - val_precision: 0.9062 - val_recall: 0.9062 - val_f1: 0.9062 - val_acc: 0.8983
# Epoch 30/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2646 - precision: 0.9007 - recall: 0.9007 - f1: 0.9007 - acc: 0.9021
# Epoch 30: val_loss did not improve from 0.24217
# 30/30 [==============================] - 16s 538ms/step - loss: 0.2646 - precision: 0.9007 - recall: 0.9007 - f1: 0.9007 - acc: 0.9021 - val_loss: 0.3083 - val_precision: 0.8542 - val_recall: 0.8542 - val_f1: 0.8542 - val_acc: 0.8559
# Epoch 31/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2422 - precision: 0.9028 - recall: 0.9028 - f1: 0.9028 - acc: 0.9043
# Epoch 31: val_loss did not improve from 0.24217
# 30/30 [==============================] - 17s 548ms/step - loss: 0.2422 - precision: 0.9028 - recall: 0.9028 - f1: 0.9028 - acc: 0.9043 - val_loss: 0.3649 - val_precision: 0.8828 - val_recall: 0.8828 - val_f1: 0.8828 - val_acc: 0.8729
# Epoch 32/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2002 - precision: 0.9229 - recall: 0.9229 - f1: 0.9229 - acc: 0.9213
# Epoch 32: val_loss did not improve from 0.24217
# 30/30 [==============================] - 16s 532ms/step - loss: 0.2002 - precision: 0.9229 - recall: 0.9229 - f1: 0.9229 - acc: 0.9213 - val_loss: 0.3675 - val_precision: 0.8932 - val_recall: 0.8932 - val_f1: 0.8932 - val_acc: 0.8983
# Epoch 33/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1514 - precision: 0.9347 - recall: 0.9347 - f1: 0.9347 - acc: 0.9404
# Epoch 33: val_loss did not improve from 0.24217
# 30/30 [==============================] - 16s 535ms/step - loss: 0.1514 - precision: 0.9347 - recall: 0.9347 - f1: 0.9347 - acc: 0.9404 - val_loss: 0.3165 - val_precision: 0.9297 - val_recall: 0.9297 - val_f1: 0.9297 - val_acc: 0.9237
# Epoch 34/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1070 - precision: 0.9563 - recall: 0.9563 - f1: 0.9563 - acc: 0.9553
# Epoch 34: val_loss did not improve from 0.24217
# 30/30 [==============================] - 16s 531ms/step - loss: 0.1070 - precision: 0.9563 - recall: 0.9563 - f1: 0.9563 - acc: 0.9553 - val_loss: 0.2892 - val_precision: 0.9219 - val_recall: 0.9219 - val_f1: 0.9219 - val_acc: 0.9153
# Epoch 35/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1139 - precision: 0.9563 - recall: 0.9563 - f1: 0.9563 - acc: 0.9553
# Epoch 35: val_loss did not improve from 0.24217
# 30/30 [==============================] - 16s 531ms/step - loss: 0.1139 - precision: 0.9563 - recall: 0.9563 - f1: 0.9563 - acc: 0.9553 - val_loss: 0.2544 - val_precision: 0.9219 - val_recall: 0.9219 - val_f1: 0.9219 - val_acc: 0.9153
# Epoch 36/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1131 - precision: 0.9542 - recall: 0.9542 - f1: 0.9542 - acc: 0.9532
# Epoch 36: val_loss improved from 0.24217 to 0.19766, saving model to model_fold_1.h5
# 30/30 [==============================] - 17s 565ms/step - loss: 0.1131 - precision: 0.9542 - recall: 0.9542 - f1: 0.9542 - acc: 0.9532 - val_loss: 0.1977 - val_precision: 0.9609 - val_recall: 0.9609 - val_f1: 0.9609 - val_acc: 0.9576
# Epoch 37/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1129 - precision: 0.9583 - recall: 0.9583 - f1: 0.9583 - acc: 0.9574
# Epoch 37: val_loss did not improve from 0.19766
# 30/30 [==============================] - 17s 537ms/step - loss: 0.1129 - precision: 0.9583 - recall: 0.9583 - f1: 0.9583 - acc: 0.9574 - val_loss: 2.0081 - val_precision: 0.5885 - val_recall: 0.5885 - val_f1: 0.5885 - val_acc: 0.5678
# Epoch 38/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1978 - precision: 0.9500 - recall: 0.9500 - f1: 0.9500 - acc: 0.9489
# Epoch 38: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 543ms/step - loss: 0.1978 - precision: 0.9500 - recall: 0.9500 - f1: 0.9500 - acc: 0.9489 - val_loss: 0.3171 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8644
# Epoch 39/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2017 - precision: 0.9229 - recall: 0.9229 - f1: 0.9229 - acc: 0.9213
# Epoch 39: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 534ms/step - loss: 0.2017 - precision: 0.9229 - recall: 0.9229 - f1: 0.9229 - acc: 0.9213 - val_loss: 0.6180 - val_precision: 0.8125 - val_recall: 0.8125 - val_f1: 0.8125 - val_acc: 0.8390
# Epoch 40/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2279 - precision: 0.9062 - recall: 0.9062 - f1: 0.9062 - acc: 0.9043
# Epoch 40: val_loss did not improve from 0.19766
# 30/30 [==============================] - 17s 545ms/step - loss: 0.2279 - precision: 0.9062 - recall: 0.9062 - f1: 0.9062 - acc: 0.9043 - val_loss: 0.2789 - val_precision: 0.9375 - val_recall: 0.9375 - val_f1: 0.9375 - val_acc: 0.9322
# Found 470 validated image filenames belonging to 2 classes.
# Found 118 validated image filenames belonging to 2 classes.
# Epoch 1/40
# 30/30 [==============================] - ETA: 0s - loss: 0.5063 - precision: 0.7819 - recall: 0.7819 - f1: 0.7819 - acc: 0.7809
# Epoch 1: val_loss did not improve from 0.19766
# 30/30 [==============================] - 42s 574ms/step - loss: 0.5063 - precision: 0.7819 - recall: 0.7819 - f1: 0.7819 - acc: 0.7809 - val_loss: 0.4988 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7712
# Epoch 2/40
# 30/30 [==============================] - ETA: 0s - loss: 0.3873 - precision: 0.8097 - recall: 0.8097 - f1: 0.8097 - acc: 0.8128
# Epoch 2: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 541ms/step - loss: 0.3873 - precision: 0.8097 - recall: 0.8097 - f1: 0.8097 - acc: 0.8128 - val_loss: 0.4865 - val_precision: 0.7891 - val_recall: 0.7891 - val_f1: 0.7891 - val_acc: 0.7712
# Epoch 3/40
# 30/30 [==============================] - ETA: 0s - loss: 0.3674 - precision: 0.8243 - recall: 0.8243 - f1: 0.8243 - acc: 0.8277
# Epoch 3: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 543ms/step - loss: 0.3674 - precision: 0.8243 - recall: 0.8243 - f1: 0.8243 - acc: 0.8277 - val_loss: 0.5151 - val_precision: 0.7969 - val_recall: 0.7969 - val_f1: 0.7969 - val_acc: 0.7797
# Epoch 4/40
# 30/30 [==============================] - ETA: 0s - loss: 0.3213 - precision: 0.8486 - recall: 0.8486 - f1: 0.8486 - acc: 0.8489
# Epoch 4: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 538ms/step - loss: 0.3213 - precision: 0.8486 - recall: 0.8486 - f1: 0.8486 - acc: 0.8489 - val_loss: 0.8472 - val_precision: 0.7786 - val_recall: 0.7786 - val_f1: 0.7786 - val_acc: 0.7881
# Epoch 5/40
# 30/30 [==============================] - ETA: 0s - loss: 0.
val_loss did not improve from 0.19766
# 30/30 [==============================] - 17s 549ms/step - loss: 0.2620 - precision: 0.8819 - recall: 0.8819 - f1: 0.8819 - acc: 0.8830 - val_loss: 0.8110 - val_precision: 0.7344 - val_recall: 0.7344 - val_f1: 0.7344 - val_acc: 0.7542
# Epoch 24/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2253 - precision: 0.9056 - recall: 0.9056 - f1: 0.9056 - acc: 0.9106
# Epoch 24: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 537ms/step - loss: 0.2253 - precision: 0.9056 - recall: 0.9056 - f1: 0.9056 - acc: 0.9106 - val_loss: 0.6670 - val_precision: 0.7240 - val_recall: 0.7240 - val_f1: 0.7240 - val_acc: 0.7288
# Epoch 25/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1796 - precision: 0.9312 - recall: 0.9312 - f1: 0.9312 - acc: 0.9298
# Epoch 25: val_loss did not improve from 0.19766
# 30/30 [==============================] - 17s 545ms/step - loss: 0.1796 - precision: 0.9312 - recall: 0.9312 - f1: 0.9312 - acc: 0.9298 - val_loss: 0.3749 - val_precision: 0.9089 - val_recall: 0.9089 - val_f1: 0.9089 - val_acc: 0.9153
# Epoch 26/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1328 - precision: 0.9403 - recall: 0.9403 - f1: 0.9403 - acc: 0.9426
# Epoch 26: val_loss did not improve from 0.19766
# 30/30 [==============================] - 17s 547ms/step - loss: 0.1328 - precision: 0.9403 - recall: 0.9403 - f1: 0.9403 - acc: 0.9426 - val_loss: 0.3675 - val_precision: 0.9141 - val_recall: 0.9141 - val_f1: 0.9141 - val_acc: 0.9068
# Epoch 27/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1261 - precision: 0.9479 - recall: 0.9479 - f1: 0.9479 - acc: 0.9468
# Epoch 27: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 539ms/step - loss: 0.1261 - precision: 0.9479 - recall: 0.9479 - f1: 0.9479 - acc: 0.9468 - val_loss: 0.3357 - val_precision: 0.9141 - val_recall: 0.9141 - val_f1: 0.9141 - val_acc: 0.9068
# Epoch 28/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1189 - precision: 0.9583 - recall: 0.9583 - f1: 0.9583 - acc: 0.9574
# Epoch 28: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 538ms/step - loss: 0.1189 - precision: 0.9583 - recall: 0.9583 - f1: 0.9583 - acc: 0.9574 - val_loss: 0.3385 - val_precision: 0.8802 - val_recall: 0.8802 - val_f1: 0.8802 - val_acc: 0.8983
# Epoch 29/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1946 - precision: 0.9215 - recall: 0.9215 - f1: 0.9215 - acc: 0.9234
# Epoch 29: val_loss did not improve from 0.19766
# 30/30 [==============================] - 17s 546ms/step - loss: 0.1946 - precision: 0.9215 - recall: 0.9215 - f1: 0.9215 - acc: 0.9234 - val_loss: 0.7678 - val_precision: 0.8854 - val_recall: 0.8854 - val_f1: 0.8854 - val_acc: 0.8898
# Epoch 30/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2129 - precision: 0.9076 - recall: 0.9076 - f1: 0.9076 - acc: 0.9128
# Epoch 30: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 539ms/step - loss: 0.2129 - precision: 0.9076 - recall: 0.9076 - f1: 0.9076 - acc: 0.9128 - val_loss: 0.4357 - val_precision: 0.8698 - val_recall: 0.8698 - val_f1: 0.8698 - val_acc: 0.8729
# Epoch 31/40
# ...
# Epoch 4/40
# 30/30 [==============================] - ETA: 0s - loss: 0.3639 - precision: 0.8515 - recall: 0.8515 - f1: 0.8515 - acc: 0.8514
# Epoch 4: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 533ms/step - loss: 0.3639 - precision: 0.8515 - recall: 0.8515 - f1: 0.8515 - acc: 0.8514 - val_loss: 0.4806 - val_precision: 0.8031 - val_recall: 0.8031 - val_f1: 0.8031 - val_acc: 0.8034
# Epoch 5/40
# 30/30 [==============================] - ETA: 0s - loss: 0.3966 - precision: 0.8286 - recall: 0.8286 - f1: 0.8286 - acc: 0.8280
# Epoch 5: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 533ms/step - loss: 0.3966 - precision: 0.8286 - recall: 0.8286 - f1: 0.8286 - acc: 0.8280 - val_loss: 0.6025 - val_precision: 0.6281 - val_recall: 0.6281 - val_f1: 0.6281 - val_acc: 0.6496
# Epoch 6/40
# 30/30 [==============================] - ETA: 0s - loss: 0.
val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 543ms/step - loss: 0.1317 - precision: 0.9625 - recall: 0.9625 - f1: 0.9625 - acc: 0.9618 - val_loss: 0.2948 - val_precision: 0.8891 - val_recall: 0.8891 - val_f1: 0.8891 - val_acc: 0.8974
# Epoch 35/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1250 - precision: 0.9479 - recall: 0.9479 - f1: 0.9479 - acc: 0.9469
# Epoch 35: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 535ms/step - loss: 0.1250 - precision: 0.9479 - recall: 0.9479 - f1: 0.9479 - acc: 0.9469 - val_loss: 0.2788 - val_precision: 0.9141 - val_recall: 0.9141 - val_f1: 0.9141 - val_acc: 0.9060
# Epoch 36/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1189 - precision: 0.9625 - recall: 0.9625 - f1: 0.9625 - acc: 0.9618
# Epoch 36: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 530ms/step - loss: 0.1189 - precision: 0.9625 - recall: 0.9625 - f1: 0.9625 - acc: 0.9618 - val_loss: 0.3771 - val_precision: 0.8969 - val_recall: 0.8969 - val_f1: 0.8969 - val_acc: 0.9060
# Epoch 37/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1240 - precision: 0.9488 - recall: 0.9488 - f1: 0.9488 - acc: 0.9533
# Epoch 37: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 541ms/step - loss: 0.1240 - precision: 0.9488 - recall: 0.9488 - f1: 0.9488 - acc: 0.9533 - val_loss: 0.5125 - val_precision: 0.8578 - val_recall: 0.8578 - val_f1: 0.8578 - val_acc: 0.8632
# Epoch 38/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2342 - precision: 0.9167 - recall: 0.9167 - f1: 0.9167 - acc: 0.9151
# Epoch 38: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 558ms/step - loss: 0.2342 - precision: 0.9167 - recall: 0.9167 - f1: 0.9167 - acc: 0.9151 - val_loss: 0.4122 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8632
# Epoch 39/40
# 30/30 [==============================] - ETA: 0s - loss: 0.2710 - precision: 0.8952 - recall: 0.8952 - f1: 0.8952 - acc: 0.8960
# Epoch 39: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 542ms/step - loss: 0.2710 - precision: 0.8952 - recall: 0.8952 - f1: 0.8952 - acc: 0.8960 - val_loss: 0.5879 - val_precision: 0.8672 - val_recall: 0.8672 - val_f1: 0.8672 - val_acc: 0.8547
# Epoch 40/40
# 30/30 [==============================] - ETA: 0s - loss: 0.1986 - precision: 0.9244 - recall: 0.9244 - f1: 0.9244 - acc: 0.9257
# Epoch 40: val_loss did not improve from 0.19766
# 30/30 [==============================] - 16s 543ms/step - loss: 0.1986 - precision: 0.9244 - recall: 0.9244 - f1: 0.9244 - acc: 0.9257 - val_loss: 0.5123 - val_precision: 0.8906 - val_recall: 0.8906 - val_f1: 0.8906 - val_acc: 0.8803
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Assuming the same rescaling was applied to the training data
test_datagen = ImageDataGenerator(rescale=1./255)

# Replace the following path with the path to your test data
test_data_path = '/content/drive/MyDrive/eardrum2/crop_data/test/'

test_generator = test_datagen.flow_from_directory(
    test_data_path,
    target_size=(299, 299),  # Make sure to match the input size of your model
    color_mode='rgb',  # or 'grayscale' depending on your model
    batch_size=16,  # Can be adjusted according to your needs
    class_mode='categorical',  # Use 'binary' for binary classification
    shuffle=False  # Important for maintaining order
)

# Note: If your test data is in a DataFrame, use flow_from_dataframe instead
# Out:
# Found 106 images belonging to 2 classes.

# %%
# Load the best model
best_model = load_model("/content/model_fold_1.h5",
                        custom_objects={'precision': precision,
                                          'recall': recall,
                                          'f1': f1})

# Evaluate the best model on test data
test_loss, test_precision, test_recall, test_f1, test_accuracy = best_model.evaluate(test_generator)
# Out:
# 7/7 [==============================] - 50s 8s/step - loss: 0.4062 - precision: 0.8446 - recall: 0.8446 - f1: 0.8446 - acc: 0.8585

# %%
best_model = load_model("/content/drive/MyDrive/eardrum/model/crop_model.h5",
                        custom_objects={'precision': precision,
                                          'recall': recall,
                                          'f1': f1})

# %%
print("Test Loss: ", test_loss)
print("Test Precision: ", test_precision)
print("Test Recall: ", test_recall)
print("Test F1: ", test_f1)
print("Test Accuracy: ", test_accuracy)
# Out:
# Test Loss:  0.4061555564403534
# Test Precision:  0.8446428179740906
# Test Recall:  0.8446428179740906
# Test F1:  0.8446428179740906
# Test Accuracy:  0.8584905862808228

# %% [markdown]
# ### ※ 세션 내에 모델 저장했을 경우, 드라이브에 모델 저장하기(선택)

# %%
# 모델 저장

# 새로운 경로 설정
new_model_path = "/content/drive/MyDrive/eardrum/model/"

best_model.save(new_model_path + "crop_model.h5") # 모델 이름 수정할 것
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # 3. Check Model Performance

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['loss'], 'r', label = 'Train Loss')
plt.plot(history.history['val_loss'], 'b', label = 'Val Loss')
plt.title('XceptionNet, Training and Validation Loss')
plt.legend()

plt.show()

plt.plot(history.history['acc'], 'r', label = 'Train Accuracy')
plt.plot(history.history['val_acc'], 'b', label = 'Val Accuracy')
plt.title('XceptionNet, Training and Validation Accuracy')
plt.legend()

plt.show()

# %%
class_indices = train_generator.class_indices
# reversing the dictionary
index_class = {v: k for k, v in class_indices.items()}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0159d63c89bb> in <cell line: 1>()
# ----> 1 class_indices = train_generator.class_indices
#       2 # reversing the dictionary
#       3 index_class = {v: k for k, v in class_indices.items()}
#
# NameError: name 'train_generator' is not defined

# %%
# class_indices = test_generator.class_indices
# # reversing the dictionary
# index_class = {v: k for k, v in class_indices.items()}

# %%
index_class
# Out:
# {0: 'Abnormal', 1: 'Normal'}

# %%
y_pred = best_model.predict(test_generator)
predicted_classes = np.argmax(y_pred, axis=1)
# Out:
# 7/7 [==============================] - 65s 10s/step

# %%
true_classes = test_generator.classes

# %%
error_indices = np.where(predicted_classes != true_classes)[0]

# %% [markdown]
# # test data에 대해 잘못 예측한 경우

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# let's say you want to see the first 5 misclassified images
for i in range(5):
    error_index = error_indices[i]

    img_path = test_generator.filepaths[error_index]
    img = image.load_img(img_path, target_size=(224, 224))  # assuming this was your input size

    true_label = index_class[true_classes[error_index]]
    predicted_label = index_class[predicted_classes[error_index]]

    plt.figure()
    plt.imshow(img)
    plt.title(f"True label: {true_label} \n Predicted label: {predicted_label}")
    plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = list(test_generator.class_indices.keys())  # get the labels as a list

# %%
class_labels
# Out:
# ['Abnormal', 'Normal']

# %%
from sklearn.metrics import confusion_matrix, classification_report

conf_matrix = confusion_matrix(true_classes, predicted_classes)

# %%
conf_matrix
# Out:
# array([[17,  8],
#        [ 7, 74]])

# %%
print(classification_report(true_classes, predicted_classes, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.7083    0.6800    0.6939        25
#            1     0.9024    0.9136    0.9080        81
#
#     accuracy                         0.8585       106
#    macro avg     0.8054    0.7968    0.8009       106
# weighted avg     0.8567    0.8585    0.8575       106

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the font scale
sns.set(font_scale=4)  # Adjust the value as needed

plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # F1 score
