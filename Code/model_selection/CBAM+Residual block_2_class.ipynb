# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Library

# %%
import os
import random
from collections import defaultdict
import numpy as np
import shutil
import matplotlib.pyplot as plt
import cv2
import imageio.v2 as iio  # Import imageio.v2 instead of imageio
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# %%
from keras.layers import *
from keras.callbacks import *
from keras.optimizers import *

# %% [markdown]
# # 1. Data Preprocessing

# %% [markdown]
# ## 1) 데이터 수 확인

# %%
import os

def count_files_in_directory(directory_path):
    return len([f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))])

directory_path = '/content/drive/MyDrive/eardrum2/data_2_vs/train/'

folders = ['Normal', 'Abnormal']

for folder in folders:
  path = directory_path + folder
  print(folder, ':', count_files_in_directory(path))
# Out:
# Normal : 372
# Abnormal : 110

# %%
import os

def count_files_in_directory(directory_path):
    return len([f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))])

directory_path = '/content/drive/MyDrive/eardrum2/data_2_vs/val/'

folders = ['Normal', 'Abnormal']

for folder in folders:
  path = directory_path + folder
  print(folder, ':', count_files_in_directory(path))
# Out:
# Normal : 81
# Abnormal : 25

# %%
import os

def count_files_in_directory(directory_path):
    return len([f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))])

directory_path = '/content/drive/MyDrive/eardrum2/data_2_vs/test/'

folders = ['Normal', 'Abnormal']

for folder in folders:
  path = directory_path + folder
  print(folder, ':', count_files_in_directory(path))
# Out:
# Normal : 81
# Abnormal : 25

# %% [markdown]
# - 파일 format 확인

# %%
def unique_file_formats_in_directory(directory_path):
    file_formats = {os.path.splitext(f)[1].lower() for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))}
    return file_formats

for folder in folders:
    path = directory_path + folder
    unique_formats = unique_file_formats_in_directory(path)
    print(folder, ":", unique_formats)
# Out:
# Normal : {'.png'}
# Abnormal : {'.png'}

# %% [markdown]
# ## 2) 데이터 분할 -> ※ 다시 실행 하지 말것!!!

# %%
import os
import random
from collections import defaultdict

# Define the categories and their corresponding image counts
categories = {
    "Normal": 534,
    "AOM": 119,
    "CSOM": 63,
    "Earwax": 140,
    "OE": 41,
    "Tympanoskleros": 28
}

# Define the desired proportions for train, validation, and test sets
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Calculate the total number of images in the dataset
total_images = sum(categories.values())
print(total_images)
# Out:
# 925

# %%
import os
import numpy as np
import shutil

# Defining your directories
base_dir = '/content/drive/MyDrive/eardrum/data/'
base_dirs = [os.path.join(base_dir, d) for d in os.listdir(base_dir)]

train_dir = '/content/drive/MyDrive/eardrum/new_data/train'
val_dir = '/content/drive/MyDrive/eardrum/new_data/val'
test_dir = '/content/drive/MyDrive/eardrum/new_data/test'

# %%
base_dirs
# Out:
# ['/content/drive/MyDrive/eardrum/data/Earwax',
#  '/content/drive/MyDrive/eardrum/data/Normal',
#  '/content/drive/MyDrive/eardrum/data/CSOM',
#  '/content/drive/MyDrive/eardrum/data/AOM',
#  '/content/drive/MyDrive/eardrum/data/OE',
#  '/content/drive/MyDrive/eardrum/data/Tympanoskleros']

# %%
# Ratio of splitting
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Iterate over all directories (classes) in your base directory
for dir_path in base_dirs: # -> 1분 40초 소요
    class_name = os.path.basename(dir_path)

    # Create corresponding directories in train, val, test directories
    os.makedirs(os.path.join(train_dir, class_name), exist_ok=True)
    os.makedirs(os.path.join(val_dir, class_name), exist_ok=True)
    os.makedirs(os.path.join(test_dir, class_name), exist_ok=True)

    # Get all file names and shuffle them
    files = os.listdir(dir_path)
    np.random.shuffle(files)

    # Calculate split indices
    train_idx = int(len(files) * train_ratio)
    val_idx = int(len(files) * (train_ratio + val_ratio))

    # Split file names
    train_files = files[:train_idx]
    val_files = files[train_idx:val_idx]
    test_files = files[val_idx:]

    # Move files to corresponding directories
    for file_name in train_files:
        shutil.copy(os.path.join(dir_path, file_name), os.path.join(train_dir, class_name, file_name))

    for file_name in val_files:
        shutil.copy(os.path.join(dir_path, file_name), os.path.join(val_dir, class_name, file_name))

    for file_name in test_files:
        shutil.copy(os.path.join(dir_path, file_name), os.path.join(test_dir, class_name, file_name))

# %%
new_data_path = '/content/drive/MyDrive/eardrum/new_data/'

folders = ['Normal', 'AOM', 'CSOM', 'Earwax', 'OE', 'Tympanoskleros']

print("Train Set:")
for folder in folders:
  path = new_data_path + 'train/'+folder
  print(folder, ':', count_files_in_directory(path))

print("\nVal Set:")
for folder in folders:
  path = new_data_path + 'val/'+folder
  print(folder, ':', count_files_in_directory(path))

print("\nTest Set:")
for folder in folders:
  path = new_data_path + 'test/'+folder
  print(folder, ':', count_files_in_directory(path))
# Out:
# Train Set:
# Normal : 373
# AOM : 83
# CSOM : 44
# Earwax : 98
# OE : 28
# Tympanoskleros : 19
#
# Val Set:
# Normal : 80
# AOM : 18
# CSOM : 9
# Earwax : 21
# OE : 6
# Tympanoskleros : 4
#
# Test Set:
# Normal : 81
# AOM : 18
# CSOM : 10
# Earwax : 21
# OE : 7
# Tympanoskleros : 5

# %% [markdown]
# ## 3) ImageDataGenerator

# %% [markdown]
# - 임의로 뽑아서 시각화

# %%
train_dir = '/content/drive/MyDrive/eardrum2/data_2_vs/train'
val_dir = '/content/drive/MyDrive/eardrum2/data_2_vs/val'
test_dir = '/content/drive/MyDrive/eardrum2/data_2_vs/test'

# %% [markdown]
# - image shape : (500, 500, 3)

# %%
from keras.preprocessing.image import ImageDataGenerator

# 고막 내시경에 적합한 데이터 증강 방법 적용 -> 수정할 것
train_datagen = ImageDataGenerator(
                                  # rotation_range=40,           # 랜덤하게 이미지 회전 각도 설정 (0~40도 사이)
                                  # horizontal_flip=True,          # 수평 방향으로 랜덤하게 이미지 뒤집기
                                  # vertical_flip=True,            # 수직 방향으로 랜덤하게 이미지 뒤집기
                                  # zoom_range=(0.8, 1),           # 랜덤하게 확대/축소 범위 설정, 0.7: 확대, 1: 원본크기와 동일
                                  #  shear_range = 0.2,           # 랜덤 전단 변환 범위 설정
                                  #  fill_mode = 'nearest',       # 이동으로 인한 빈 픽셀을 가장 가까운 값으로 채우는 방식
                                  # brightness_range=[0.7, 1.3],  # 명도 범위
                                  rescale = 1/255.0)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Load images from directories and apply augmentations
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(224, 224),
        batch_size=16,
        class_mode='categorical',
        color_mode='rgb',  # TIFF 파일을 RGB 색상 모드로 로드
        interpolation='nearest')  # 이미지 보간 방법 설정


validation_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(224, 224),
        batch_size=16,
        class_mode='categorical',
        color_mode='rgb',  # TIFF 파일을 RGB 색상 모드로 로드
        interpolation='nearest')  # 이미지 보간 방법 설정

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=16,
        class_mode='categorical',
        color_mode='rgb',  # TIFF 파일을 RGB 색상 모드로 로드
        interpolation='nearest')  # 이미지 보간 방법 설정
# Out:
# Found 482 images belonging to 2 classes.
# Found 106 images belonging to 2 classes.
# Found 106 images belonging to 2 classes.

# %%
class_indices = train_generator.class_indices
# reversing the dictionary
index_class = {v: k for k, v in class_indices.items()}

# %%
index_class
# Out:
# {0: 'Abnormal', 1: 'Normal'}

# %% [markdown]
# - 데이터 증강된 이미지 확인해보기

# %%
# plot the augmented train images
import matplotlib.pyplot as plt

# Set the number of images to plot
num_images = 5

# Get a batch of augmented images and labels from train_data
augmented_images, augmented_labels = next(train_generator)

# Plot the augmented images
fig, axes = plt.subplots(1, num_images, figsize=(12, 6))

for i in range(num_images):
    image = augmented_images[i]
    label = augmented_labels[i]

    axes[i].imshow(image)
    # axes[i].set_title(f'Label: {label}')

    class_cat = index_class[np.argmax(label)]
    axes[i].set_title(f'Class: {class_cat}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Model

# %% [markdown]
# att

# %%
def cbam_block(cbam_feature, ratio=8):
    """
    Convolutional Block Attention Module(CBAM) 블록의 구현체입니다.
    https://arxiv.org/abs/1807.06521에 설명되어 있습니다.
    """
    cbam_feature = channel_attention(cbam_feature, ratio)
    cbam_feature = spatial_attention(cbam_feature)
    return cbam_feature

def channel_attention(input_feature, ratio=8):
    channel_axis = 1 if tf.keras.backend.image_data_format() == "channels_first" else -1
    channel = tf.keras.backend.int_shape(input_feature)[channel_axis]

    shared_layer_one = Dense(channel // ratio, activation='relu', kernel_initializer='he_normal', use_bias=True, bias_initializer='zeros')
    shared_layer_two = Dense(channel, kernel_initializer='he_normal', use_bias=True, bias_initializer='zeros')

    avg_pool = GlobalAveragePooling2D()(input_feature)
    avg_pool = Reshape((1, 1, channel))(avg_pool)
    avg_pool = shared_layer_one(avg_pool)
    avg_pool = shared_layer_two(avg_pool)

    max_pool = GlobalMaxPooling2D()(input_feature)
    max_pool = Reshape((1, 1, channel))(max_pool)
    max_pool = shared_layer_one(max_pool)
    max_pool = shared_layer_two(max_pool)

    cbam_feature = Add()([avg_pool, max_pool])
    cbam_feature = Activation('sigmoid')(cbam_feature)

    if tf.keras.backend.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)

    return multiply([input_feature, cbam_feature])

def spatial_attention(input_feature):
    kernel_size = 7

    if tf.keras.backend.image_data_format() == "channels_first":
        channel = tf.keras.backend.int_shape(input_feature)[1]
        cbam_feature = Permute((2, 3, 1))(input_feature)
    else:
        channel = tf.keras.backend.int_shape(input_feature)[-1]
        cbam_feature = input_feature

    avg_pool = Lambda(lambda x: tf.keras.backend.mean(x, axis=3, keepdims=True))(cbam_feature)
    max_pool = Lambda(lambda x: tf.keras.backend.max(x, axis=3, keepdims=True))(cbam_feature)
    concat = Concatenate(axis=3)([avg_pool, max_pool])
    cbam_feature = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(concat)

    if tf.keras.backend.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)

    return multiply([input_feature, cbam_feature])

# %%
# copied from https://gist.github.com/mjdietzx/5319e42637ed7ef095d430cb5c5e8c64
def residual_block(y, nb_channels, _strides=(1, 1), _project_shortcut=False):
    shortcut = y

    # down-sampling is performed with a stride of 2
    y = Conv2D(nb_channels, kernel_size=(3, 3), strides=_strides, padding='same')(y)
    y = BatchNormalization()(y)
    y = LeakyReLU()(y)

    y = Conv2D(nb_channels, kernel_size=(3, 3), strides=(1, 1), padding='same')(y)
    y = BatchNormalization()(y)

    # identity shortcuts used directly when the input and output are of the same dimensions
    if _project_shortcut or _strides != (1, 1):
        # when the dimensions increase projection shortcut is used to match dimensions (done by 1×1 convolutions)
        # when the shortcuts go across feature maps of two sizes, they are performed with a stride of 2
        shortcut = Conv2D(nb_channels, kernel_size=(1, 1), strides=_strides, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)

    y = add([shortcut, y])
    y = LeakyReLU()(y)

    return y

# %%
SHAPE = (224, 224, 3)
BATCH_SIZE = 16
EPOCHS = 50
TOTAL_CLASS_NUMBER = 2 # 2, 3

# %%
def create_model(SHAPE, TOTAL_CLASS_NUMBER):
    dropRate = 0.3

    init = Input(SHAPE)
    x = Conv2D(32, (3, 3), activation=None, padding='same')(init)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(32, (3, 3), activation=None, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x1 = MaxPooling2D((2,2))(x)

    x = Conv2D(64, (3, 3), activation=None, padding='same')(x1)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = cbam_block(x)  # cbam_block 함수의 구현이 필요합니다.
    x = residual_block(x, 64)  # residual_block 함수의 구현이 필요합니다.
    x2 = MaxPooling2D((2,2))(x)

    x = Conv2D(128, (3, 3), activation=None, padding='same')(x2)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = cbam_block(x)  # cbam_block 함수의 구현이 필요합니다.
    x = residual_block(x, 128)  # residual_block 함수의 구현이 필요합니다.
    x3 = MaxPooling2D((2,2))(x)

    ginp1 = UpSampling2D(size=(2, 2), interpolation='bilinear')(x1)
    ginp2 = UpSampling2D(size=(4, 4), interpolation='bilinear')(x2)
    ginp3 = UpSampling2D(size=(8, 8), interpolation='bilinear')(x3)

    hypercolumn = Concatenate()([ginp1, ginp2, ginp3])
    gap = GlobalAveragePooling2D()(hypercolumn)

    x = Dense(256, activation=None)(gap)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropRate)(x)

    x = Dense(256, activation=None)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    y = Dense(TOTAL_CLASS_NUMBER, activation='softmax')(x)

    model = Model(init, y)
    return model

# %%
model = create_model(SHAPE, TOTAL_CLASS_NUMBER)

# 모델 컴파일
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()

# %% [markdown]
# - ReduceLROnPlateau:
#   - 검증 손실(val_loss)이 10번의 에포크(patience)동안 향상되지 않으면 학습률(learning rate)을 0.1배(factor)로 감소시킵니다.
#   - 이는 학습 도중 학습률을 동적으로 조절하여 학습을 안정화시키는 데 사용됩니다.
# - EarlyStopping:
#   - 검증 손실(val_loss)이 20번의 에포크(patience)동안 향상되지 않으면 학습을 조기에 종료합니다.
#   - 이를 통해 과적합을 방지하고 효율적인 학습을 할 수 있습니다.
# - ModelCheckpoint:
#   - 검증 손실(val_loss)이 가장 낮을 때 모델을 저장합니다.
#   - 이를 통해 최상의 성능을 보이는 모델을 저장하여 나중에 재사용할 수 있습니다.

# %%
# 활성 세션 내 모델 저장소 디렉토리 생성
os.makedirs('/content/model/')

# %%
ely_cb = EarlyStopping(monitor='val_loss', patience=20, mode='min', verbose=1)

model_path = "/content/model/"  # 모델 저장 경로(활성 세션 내)
checkpoint_cb = ModelCheckpoint(filepath=model_path + "custom_model.h5", save_best_only=True,
                                monitor='val_loss', mode='min', verbose=1)

# 훈련 시작
history_aug = model.fit(train_generator, validation_data=validation_generator,
                        epochs=70, callbacks=[ely_cb, checkpoint_cb])
# Out:
# Epoch 1/70
# 31/31 [==============================] - ETA: 0s - loss: 0.5666 - accuracy: 0.7448
# Epoch 1: val_loss improved from inf to 0.60271, saving model to /content/model/custom_model.h5
# 31/31 [==============================] - 199s 6s/step - loss: 0.5666 - accuracy: 0.7448 - val_loss: 0.6027 - val_accuracy: 0.7642
# Epoch 2/70
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 31/31 [==============================] - ETA: 0s - loss: 0.4534 - accuracy: 0.8133
# Epoch 2: val_loss improved from 0.60271 to 0.59070, saving model to /content/model/custom_model.h5
# 31/31 [==============================] - 10s 312ms/step - loss: 0.4534 - accuracy: 0.8133 - val_loss: 0.5907 - val_accuracy: 0.7642
# Epoch 3/70
# 31/31 [==============================] - ETA: 0s - loss: 0.4630 - accuracy: 0.7946
# Epoch 3: val_loss improved from 0.59070 to 0.55569, saving model to /content/model/custom_model.h5
# 31/31 [==============================] - 8s 269ms/step - loss: 0.4630 - accuracy: 0.7946 - val_loss: 0.5557 - val_accuracy: 0.7642
# Epoch 4/70
# 31/31 [==============================] - ETA: 0s - loss: 0.4801 - accuracy: 0.8050
# Epoch 4: val_loss did not improve from 0.55569
# 31/31 [==============================] - 9s 274ms/step - loss: 0.4801 - accuracy: 0.8050 - val_loss: 0.5646 - val_accuracy: 0.7642
# Epoch 5/70
# 31/31 [==============================] - ETA: 0s - loss: 0.4947 - accuracy: 0.7842
# Epoch 5: val_loss improved from 0.55569 to 0.52609, saving model to /content/model/custom_model.h5
# 31/31 [==============================] - 10s 302ms/step - loss: 0.4947 - accuracy: 0.7842 - val_loss: 0.5261 - val_accuracy: 0.7642
# Epoch 6/70
# 31/31 [==============================] - ETA: 0s - loss: 0.4930 - accuracy: 0.7842
# Epoch 6: val_loss did not improve from 0.52609
# 31/31 [==============================] - 10s 312ms/step - loss: 0.4930 - accuracy: 0.7842 - val_loss: 0.5338 - val_accuracy: 0.7642
# Epoch 7/70
# 31/31 [==============================] - ETA: 0s - loss: 0.4284 - accuracy: 0.8071
# Epoch 7: val_loss did not improve from 0.52609
# 31/31 [==============================] - 8s 260ms/step - loss: 0.4284 - accuracy: 0.8071 - val_loss: 0.9973 - val_accuracy: 0.7642
# Epoch 8/70
# 31/31 [==============================] - ETA: 0s - loss: 0.4421 - accuracy: 0.8361
# Epoch 8: val_loss did not improve from 0.52609
# 31/31 [==============================] - 9s 293ms/step - loss: 0.4421 - accuracy: 0.8361 - val_loss: 0.5829 - val_accuracy: 0.7642
# Epoch 9/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3891 - accuracy: 0.8320
# Epoch 9: val_loss did not improve from 0.52609
# 31/31 [==============================] - 9s 289ms/step - loss: 0.3891 - accuracy: 0.8320 - val_loss: 0.7696 - val_accuracy: 0.7642
# Epoch 10/70
# 31/31 [==============================] - ETA: 0s - loss: 0.4234 - accuracy: 0.8133
# Epoch 10: val_loss did not improve from 0.52609
# 31/31 [==============================] - 8s 253ms/step - loss: 0.4234 - accuracy: 0.8133 - val_loss: 1.3802 - val_accuracy: 0.7642
# Epoch 11/70
# 31/31 [==============================] - ETA: 0s - loss: 0.4337 - accuracy: 0.8320
# Epoch 11: val_loss did not improve from 0.52609
# 31/31 [==============================] - 9s 295ms/step - loss: 0.4337 - accuracy: 0.8320 - val_loss: 1.5233 - val_accuracy: 0.7642
# Epoch 12/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3788 - accuracy: 0.8278
# Epoch 12: val_loss did not improve from 0.52609
# 31/31 [==============================] - 9s 303ms/step - loss: 0.3788 - accuracy: 0.8278 - val_loss: 1.4323 - val_accuracy: 0.7642
# Epoch 13/70
# 31/31 [==============================] - ETA: 0s - loss: 0.4093 - accuracy: 0.8361
# Epoch 13: val_loss did not improve from 0.52609
# 31/31 [==============================] - 8s 253ms/step - loss: 0.4093 - accuracy: 0.8361 - val_loss: 2.2884 - val_accuracy: 0.7642
# Epoch 14/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3773 - accuracy: 0.8382
# Epoch 14: val_loss did not improve from 0.52609
# 31/31 [==============================] - 9s 270ms/step - loss: 0.3773 - accuracy: 0.8382 - val_loss: 1.8992 - val_accuracy: 0.7642
# Epoch 15/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3878 - accuracy: 0.8361
# Epoch 15: val_loss did not improve from 0.52609
# 31/31 [==============================] - 9s 300ms/step - loss: 0.3878 - accuracy: 0.8361 - val_loss: 1.8797 - val_accuracy: 0.7642
# Epoch 16/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3371 - accuracy: 0.8610
# Epoch 16: val_loss did not improve from 0.52609
# 31/31 [==============================] - 9s 297ms/step - loss: 0.3371 - accuracy: 0.8610 - val_loss: 1.6719 - val_accuracy: 0.7642
# Epoch 17/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3693 - accuracy: 0.8423
# Epoch 17: val_loss did not improve from 0.52609
# 31/31 [==============================] - 8s 266ms/step - loss: 0.3693 - accuracy: 0.8423 - val_loss: 1.2401 - val_accuracy: 0.7642
# Epoch 18/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3410 - accuracy: 0.8465
# Epoch 18: val_loss did not improve from 0.52609
# 31/31 [==============================] - 9s 297ms/step - loss: 0.3410 - accuracy: 0.8465 - val_loss: 1.2368 - val_accuracy: 0.7642
# Epoch 19/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3897 - accuracy: 0.8382
# Epoch 19: val_loss improved from 0.52609 to 0.45322, saving model to /content/model/custom_model.h5
# 31/31 [==============================] - 10s 309ms/step - loss: 0.3897 - accuracy: 0.8382 - val_loss: 0.4532 - val_accuracy: 0.7830
# Epoch 20/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3822 - accuracy: 0.8423
# Epoch 20: val_loss did not improve from 0.45322
# 31/31 [==============================] - 8s 252ms/step - loss: 0.3822 - accuracy: 0.8423 - val_loss: 1.7531 - val_accuracy: 0.2453
# Epoch 21/70
# 31/31 [==============================] - ETA: 0s - loss: 0.4375 - accuracy: 0.7842
# Epoch 21: val_loss did not improve from 0.45322
# 31/31 [==============================] - 9s 287ms/step - loss: 0.4375 - accuracy: 0.7842 - val_loss: 0.6143 - val_accuracy: 0.7642
# Epoch 22/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3752 - accuracy: 0.8320
# Epoch 22: val_loss did not improve from 0.45322
# 31/31 [==============================] - 10s 316ms/step - loss: 0.3752 - accuracy: 0.8320 - val_loss: 0.7208 - val_accuracy: 0.6132
# Epoch 23/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3710 - accuracy: 0.8361
# Epoch 23: val_loss did not improve from 0.45322
# 31/31 [==============================] - 9s 302ms/step - loss: 0.3710 - accuracy: 0.8361 - val_loss: 0.6179 - val_accuracy: 0.7642
# Epoch 24/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3630 - accuracy: 0.8382
# Epoch 24: val_loss did not improve from 0.45322
# 31/31 [==============================] - 9s 273ms/step - loss: 0.3630 - accuracy: 0.8382 - val_loss: 0.5552 - val_accuracy: 0.7925
# Epoch 25/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3527 - accuracy: 0.8548
# Epoch 25: val_loss did not improve from 0.45322
# 31/31 [==============================] - 9s 292ms/step - loss: 0.3527 - accuracy: 0.8548 - val_loss: 0.8399 - val_accuracy: 0.7736
# Epoch 26/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3699 - accuracy: 0.8589
# Epoch 26: val_loss did not improve from 0.45322
# 31/31 [==============================] - 10s 306ms/step - loss: 0.3699 - accuracy: 0.8589 - val_loss: 0.8277 - val_accuracy: 0.7736
# Epoch 27/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3386 - accuracy: 0.8506
# Epoch 27: val_loss did not improve from 0.45322
# 31/31 [==============================] - 8s 257ms/step - loss: 0.3386 - accuracy: 0.8506 - val_loss: 0.8667 - val_accuracy: 0.5849
# Epoch 28/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3527 - accuracy: 0.8423
# Epoch 28: val_loss did not improve from 0.45322
# 31/31 [==============================] - 10s 307ms/step - loss: 0.3527 - accuracy: 0.8423 - val_loss: 1.2274 - val_accuracy: 0.4245
# Epoch 29/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3507 - accuracy: 0.8568
# Epoch 29: val_loss did not improve from 0.45322
# 31/31 [==============================] - 10s 308ms/step - loss: 0.3507 - accuracy: 0.8568 - val_loss: 0.5878 - val_accuracy: 0.7642
# Epoch 30/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3987 - accuracy: 0.8216
# Epoch 30: val_loss did not improve from 0.45322
# 31/31 [==============================] - 8s 261ms/step - loss: 0.3987 - accuracy: 0.8216 - val_loss: 0.9024 - val_accuracy: 0.4340
# Epoch 31/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3986 - accuracy: 0.8402
# Epoch 31: val_loss did not improve from 0.45322
# 31/31 [==============================] - 9s 302ms/step - loss: 0.3986 - accuracy: 0.8402 - val_loss: 0.7873 - val_accuracy: 0.5472
# Epoch 32/70
# 31/31 [==============================] - ETA: 0s - loss: 0.4047 - accuracy: 0.8216
# Epoch 32: val_loss did not improve from 0.45322
# 31/31 [==============================] - 9s 278ms/step - loss: 0.4047 - accuracy: 0.8216 - val_loss: 0.4611 - val_accuracy: 0.8208
# Epoch 33/70
# 31/31 [==============================] - ETA: 0s - loss: 0.4113 - accuracy: 0.8154
# Epoch 33: val_loss did not improve from 0.45322
# 31/31 [==============================] - 8s 257ms/step - loss: 0.4113 - accuracy: 0.8154 - val_loss: 0.6731 - val_accuracy: 0.7547
# Epoch 34/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3904 - accuracy: 0.8278
# Epoch 34: val_loss improved from 0.45322 to 0.38106, saving model to /content/model/custom_model.h5
# 31/31 [==============================] - 10s 308ms/step - loss: 0.3904 - accuracy: 0.8278 - val_loss: 0.3811 - val_accuracy: 0.8208
# Epoch 35/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3652 - accuracy: 0.8444
# Epoch 35: val_loss did not improve from 0.38106
# 31/31 [==============================] - 9s 294ms/step - loss: 0.3652 - accuracy: 0.8444 - val_loss: 0.3881 - val_accuracy: 0.8396
# Epoch 36/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3636 - accuracy: 0.8340
# Epoch 36: val_loss improved from 0.38106 to 0.38073, saving model to /content/model/custom_model.h5
# 31/31 [==============================] - 8s 263ms/step - loss: 0.3636 - accuracy: 0.8340 - val_loss: 0.3807 - val_accuracy: 0.8585
# Epoch 37/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3617 - accuracy: 0.8568
# Epoch 37: val_loss did not improve from 0.38073
# 31/31 [==============================] - 9s 299ms/step - loss: 0.3617 - accuracy: 0.8568 - val_loss: 0.4400 - val_accuracy: 0.8302
# Epoch 38/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3634 - accuracy: 0.8465
# Epoch 38: val_loss did not improve from 0.38073
# 31/31 [==============================] - 9s 295ms/step - loss: 0.3634 - accuracy: 0.8465 - val_loss: 0.9476 - val_accuracy: 0.5755
# Epoch 39/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3636 - accuracy: 0.8382
# Epoch 39: val_loss did not improve from 0.38073
# 31/31 [==============================] - 8s 258ms/step - loss: 0.3636 - accuracy: 0.8382 - val_loss: 0.5131 - val_accuracy: 0.7830
# Epoch 40/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3633 - accuracy: 0.8465
# Epoch 40: val_loss did not improve from 0.38073
# 31/31 [==============================] - 9s 298ms/step - loss: 0.3633 - accuracy: 0.8465 - val_loss: 0.3876 - val_accuracy: 0.8302
# Epoch 41/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3630 - accuracy: 0.8506
# Epoch 41: val_loss improved from 0.38073 to 0.33966, saving model to /content/model/custom_model.h5
# 31/31 [==============================] - 9s 294ms/step - loss: 0.3630 - accuracy: 0.8506 - val_loss: 0.3397 - val_accuracy: 0.8585
# Epoch 42/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3630 - accuracy: 0.8237
# Epoch 42: val_loss did not improve from 0.33966
# 31/31 [==============================] - 8s 258ms/step - loss: 0.3630 - accuracy: 0.8237 - val_loss: 0.8248 - val_accuracy: 0.6226
# Epoch 43/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3663 - accuracy: 0.8444
# Epoch 43: val_loss did not improve from 0.33966
# 31/31 [==============================] - 9s 298ms/step - loss: 0.3663 - accuracy: 0.8444 - val_loss: 0.5455 - val_accuracy: 0.7736
# Epoch 44/70
# 30/31 [============================>.] - ETA: 0s - loss: 0.3431 - accuracy: 0.8479
# Epoch 44: val_loss did not improve from 0.33966
# 31/31 [==============================] - 10s 311ms/step - loss: 0.3441 - accuracy: 0.8465 - val_loss: 0.7692 - val_accuracy: 0.6038
# Epoch 45/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3433 - accuracy: 0.8548
# Epoch 45: val_loss did not improve from 0.33966
# 31/31 [==============================] - 8s 255ms/step - loss: 0.3433 - accuracy: 0.8548 - val_loss: 0.7055 - val_accuracy: 0.6981
# Epoch 46/70
# 30/31 [============================>.] - ETA: 0s - loss: 0.3164 - accuracy: 0.8687
# Epoch 46: val_loss did not improve from 0.33966
# 31/31 [==============================] - 9s 286ms/step - loss: 0.3156 - accuracy: 0.8693 - val_loss: 0.8774 - val_accuracy: 0.5472
# Epoch 47/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3676 - accuracy: 0.8320
# Epoch 47: val_loss did not improve from 0.33966
# 31/31 [==============================] - 9s 296ms/step - loss: 0.3676 - accuracy: 0.8320 - val_loss: 0.3718 - val_accuracy: 0.8208
# Epoch 48/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3380 - accuracy: 0.8568
# Epoch 48: val_loss did not improve from 0.33966
# 31/31 [==============================] - 8s 255ms/step - loss: 0.3380 - accuracy: 0.8568 - val_loss: 0.4699 - val_accuracy: 0.7830
# Epoch 49/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3557 - accuracy: 0.8506
# Epoch 49: val_loss did not improve from 0.33966
# 31/31 [==============================] - 9s 298ms/step - loss: 0.3557 - accuracy: 0.8506 - val_loss: 0.4300 - val_accuracy: 0.7925
# Epoch 50/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.8568
# Epoch 50: val_loss did not improve from 0.33966
# 31/31 [==============================] - 9s 288ms/step - loss: 0.3265 - accuracy: 0.8568 - val_loss: 0.5814 - val_accuracy: 0.7736
# Epoch 51/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3349 - accuracy: 0.8610
# Epoch 51: val_loss did not improve from 0.33966
# 31/31 [==============================] - 8s 261ms/step - loss: 0.3349 - accuracy: 0.8610 - val_loss: 0.4041 - val_accuracy: 0.8396
# Epoch 52/70
# 30/31 [============================>.] - ETA: 0s - loss: 0.3117 - accuracy: 0.8813
# Epoch 52: val_loss did not improve from 0.33966
# 31/31 [==============================] - 9s 298ms/step - loss: 0.3116 - accuracy: 0.8817 - val_loss: 0.3848 - val_accuracy: 0.8302
# Epoch 53/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3098 - accuracy: 0.8734
# Epoch 53: val_loss did not improve from 0.33966
# 31/31 [==============================] - 9s 296ms/step - loss: 0.3098 - accuracy: 0.8734 - val_loss: 0.4003 - val_accuracy: 0.8396
# Epoch 54/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3472 - accuracy: 0.8568
# Epoch 54: val_loss did not improve from 0.33966
# 31/31 [==============================] - 8s 259ms/step - loss: 0.3472 - accuracy: 0.8568 - val_loss: 0.8123 - val_accuracy: 0.6226
# Epoch 55/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3312 - accuracy: 0.8506
# Epoch 55: val_loss did not improve from 0.33966
# 31/31 [==============================] - 9s 277ms/step - loss: 0.3312 - accuracy: 0.8506 - val_loss: 1.0206 - val_accuracy: 0.4811
# Epoch 56/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3401 - accuracy: 0.8631
# Epoch 56: val_loss did not improve from 0.33966
# 31/31 [==============================] - 9s 298ms/step - loss: 0.3401 - accuracy: 0.8631 - val_loss: 1.4152 - val_accuracy: 0.4245
# Epoch 57/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3371 - accuracy: 0.8672
# Epoch 57: val_loss did not improve from 0.33966
# 31/31 [==============================] - 8s 260ms/step - loss: 0.3371 - accuracy: 0.8672 - val_loss: 0.7998 - val_accuracy: 0.7170
# Epoch 58/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3232 - accuracy: 0.8693
# Epoch 58: val_loss did not improve from 0.33966
# 31/31 [==============================] - 9s 297ms/step - loss: 0.3232 - accuracy: 0.8693 - val_loss: 1.1192 - val_accuracy: 0.4528
# Epoch 59/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3136 - accuracy: 0.8755
# Epoch 59: val_loss did not improve from 0.33966
# 31/31 [==============================] - 9s 292ms/step - loss: 0.3136 - accuracy: 0.8755 - val_loss: 1.3033 - val_accuracy: 0.4057
# Epoch 60/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3198 - accuracy: 0.8631
# Epoch 60: val_loss did not improve from 0.33966
# 31/31 [==============================] - 8s 257ms/step - loss: 0.3198 - accuracy: 0.8631 - val_loss: 0.3874 - val_accuracy: 0.8302
# Epoch 61/70
# 31/31 [==============================] - ETA: 0s - loss: 0.3243 - accuracy: 0.8693
# Epoch 61: val_loss did not improve from 0.33966
# 31/31 [==============================] - 9s 297ms/step - loss: 0.3243 - accuracy: 0.8693 - val_loss: 0.5627 - val_accuracy: 0.6981
# Epoch 61: early stopping

# %%
# 30에폭에 30분 소요

# %% [markdown]
# ### ※ 세션 내에 모델 저장했을 경우, 드라이브에 모델 저장하기(선택)

# %%
from tensorflow.keras.models import load_model

# 저장된 모델 불러오기
loaded_model = load_model("/content/model/xception_model_1.h5")

# %%
# 모델 저장

# 새로운 경로 설정
new_model_path = "/content/drive/MyDrive/eardrum/model/"

loaded_model.save(new_model_path + "xception_model_2.h5") # 모델 이름 수정할 것

# %% [markdown]
# # 3. Check Model Performance

# %%
from matplotlib import pyplot as plt

plt.plot(history_aug.history['loss'], 'r', label = 'Train Loss')
plt.plot(history_aug.history['val_loss'], 'b', label = 'Val Loss')
plt.title('XceptionNet, Training and Validation Loss')
plt.legend()

plt.show()

plt.plot(history_aug.history['accuracy'], 'r', label = 'Train Accuracy')
plt.plot(history_aug.history['val_accuracy'], 'b', label = 'Val Accuracy')
plt.title('XceptionNet, Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_generator)

print("Test Loss: ", test_loss)
print("Test Accuracy: ", test_accuracy)
# Out:
# 7/7 [==============================] - 32s 5s/step - loss: 0.5945 - accuracy: 0.7264
# Test Loss:  0.5945314764976501
# Test Accuracy:  0.7264150977134705

# %%
index_class
# Out:
# {0: 'Abnormal', 1: 'Normal'}

# %%
y_pred = model.predict(test_generator)
predicted_classes = np.argmax(y_pred, axis=1)
# Out:
# 7/7 [==============================] - 2s 184ms/step

# %%
true_classes = test_generator.classes

# %%
error_indices = np.where(predicted_classes != true_classes)[0]

# %% [markdown]
# # test data에 대해 잘못 예측한 경우

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# let's say you want to see the first 5 misclassified images
for i in range(5):
    error_index = error_indices[i]

    img_path = test_generator.filepaths[error_index]
    img = image.load_img(img_path, target_size=(224, 224))  # assuming this was your input size

    true_label = index_class[true_classes[error_index]]
    predicted_label = index_class[predicted_classes[error_index]]

    plt.figure()
    plt.imshow(img)
    plt.title(f"True label: {true_label} \n Predicted label: {predicted_label}")
    plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = list(test_generator.class_indices.keys())  # get the labels as a list

# %%
class_labels
# Out:
# ['Abnormal', 'Normal']

# %%
from sklearn.metrics import confusion_matrix, classification_report

conf_matrix = confusion_matrix(true_classes, predicted_classes)

# %%
conf_matrix
# Out:
# array([[10, 15],
#        [36, 45]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # classification_report

# %%
print(classification_report(true_classes, predicted_classes, digits=2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.22      0.40      0.28        25
#            1       0.75      0.56      0.64        81
#
#     accuracy                           0.52       106
#    macro avg       0.48      0.48      0.46       106
# weighted avg       0.62      0.52      0.55       106

# %%
# 거의 다 Normal로 예측해버림;;;;;;;; -> 데이터 불균형 때문
# 데이터 증강이 매우매우매우매우매우 중요할듯.

# %% [markdown]
# # F1 score
