# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Library

# %%
import os
import random
from collections import defaultdict
import numpy as np
import shutil
import matplotlib.pyplot as plt
import cv2
import imageio.v2 as iio  # Import imageio.v2 instead of imageio
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# %% [markdown]
# # 1. Data Preprocessing

# %% [markdown]
# ## 1) 데이터 수 확인

# %%
import os

def count_files_in_directory(directory_path):
    return len([f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))])

directory_path = '/content/drive/MyDrive/eardrum2/data_2_vs/train/'

folders = ['Normal', 'Abnormal']

for folder in folders:
  path = directory_path + folder
  print(folder, ':', count_files_in_directory(path))
# Out:
# Normal : 372
# Abnormal : 110

# %%
import os

def count_files_in_directory(directory_path):
    return len([f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))])

directory_path = '/content/drive/MyDrive/eardrum2/data_2_vs/val/'

folders = ['Normal', 'Abnormal']

for folder in folders:
  path = directory_path + folder
  print(folder, ':', count_files_in_directory(path))
# Out:
# Normal : 81
# Abnormal : 25

# %%
import os

def count_files_in_directory(directory_path):
    return len([f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))])

directory_path = '/content/drive/MyDrive/eardrum2/data_2_vs/test/'

folders = ['Normal', 'Abnormal']

for folder in folders:
  path = directory_path + folder
  print(folder, ':', count_files_in_directory(path))
# Out:
# Normal : 81
# Abnormal : 25

# %% [markdown]
# - 파일 format 확인

# %%
def unique_file_formats_in_directory(directory_path):
    file_formats = {os.path.splitext(f)[1].lower() for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))}
    return file_formats

for folder in folders:
    path = directory_path + folder
    unique_formats = unique_file_formats_in_directory(path)
    print(folder, ":", unique_formats)
# Out:
# Normal : {'.png'}
# Abnormal : {'.png'}

# %% [markdown]
# ## 2) 데이터 분할 -> ※ 다시 실행 하지 말것!!!

# %%
import os
import random
from collections import defaultdict

# Define the categories and their corresponding image counts
categories = {
    "Normal": 534,
    "AOM": 119,
    "CSOM": 63,
    "Earwax": 140,
    "OE": 41,
    "Tympanoskleros": 28
}

# Define the desired proportions for train, validation, and test sets
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Calculate the total number of images in the dataset
total_images = sum(categories.values())
print(total_images)
# Out:
# 925

# %%
import os
import numpy as np
import shutil

# Defining your directories
base_dir = '/content/drive/MyDrive/eardrum/data/'
base_dirs = [os.path.join(base_dir, d) for d in os.listdir(base_dir)]

train_dir = '/content/drive/MyDrive/eardrum/new_data/train'
val_dir = '/content/drive/MyDrive/eardrum/new_data/val'
test_dir = '/content/drive/MyDrive/eardrum/new_data/test'

# %%
base_dirs
# Out:
# ['/content/drive/MyDrive/eardrum/data/Earwax',
#  '/content/drive/MyDrive/eardrum/data/Normal',
#  '/content/drive/MyDrive/eardrum/data/CSOM',
#  '/content/drive/MyDrive/eardrum/data/AOM',
#  '/content/drive/MyDrive/eardrum/data/OE',
#  '/content/drive/MyDrive/eardrum/data/Tympanoskleros']

# %%
# Ratio of splitting
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Iterate over all directories (classes) in your base directory
for dir_path in base_dirs: # -> 1분 40초 소요
    class_name = os.path.basename(dir_path)

    # Create corresponding directories in train, val, test directories
    os.makedirs(os.path.join(train_dir, class_name), exist_ok=True)
    os.makedirs(os.path.join(val_dir, class_name), exist_ok=True)
    os.makedirs(os.path.join(test_dir, class_name), exist_ok=True)

    # Get all file names and shuffle them
    files = os.listdir(dir_path)
    np.random.shuffle(files)

    # Calculate split indices
    train_idx = int(len(files) * train_ratio)
    val_idx = int(len(files) * (train_ratio + val_ratio))

    # Split file names
    train_files = files[:train_idx]
    val_files = files[train_idx:val_idx]
    test_files = files[val_idx:]

    # Move files to corresponding directories
    for file_name in train_files:
        shutil.copy(os.path.join(dir_path, file_name), os.path.join(train_dir, class_name, file_name))

    for file_name in val_files:
        shutil.copy(os.path.join(dir_path, file_name), os.path.join(val_dir, class_name, file_name))

    for file_name in test_files:
        shutil.copy(os.path.join(dir_path, file_name), os.path.join(test_dir, class_name, file_name))

# %%
new_data_path = '/content/drive/MyDrive/eardrum/new_data/'

folders = ['Normal', 'AOM', 'CSOM', 'Earwax', 'OE', 'Tympanoskleros']

print("Train Set:")
for folder in folders:
  path = new_data_path + 'train/'+folder
  print(folder, ':', count_files_in_directory(path))

print("\nVal Set:")
for folder in folders:
  path = new_data_path + 'val/'+folder
  print(folder, ':', count_files_in_directory(path))

print("\nTest Set:")
for folder in folders:
  path = new_data_path + 'test/'+folder
  print(folder, ':', count_files_in_directory(path))
# Out:
# Train Set:
# Normal : 373
# AOM : 83
# CSOM : 44
# Earwax : 98
# OE : 28
# Tympanoskleros : 19
#
# Val Set:
# Normal : 80
# AOM : 18
# CSOM : 9
# Earwax : 21
# OE : 6
# Tympanoskleros : 4
#
# Test Set:
# Normal : 81
# AOM : 18
# CSOM : 10
# Earwax : 21
# OE : 7
# Tympanoskleros : 5

# %% [markdown]
# ## 3) ImageDataGenerator

# %% [markdown]
# - 임의로 뽑아서 시각화

# %%
train_dir = '/content/drive/MyDrive/eardrum2/data_2_vs/train'
val_dir = '/content/drive/MyDrive/eardrum2/data_2_vs/val'
test_dir = '/content/drive/MyDrive/eardrum2/data_2_vs/test'

# %% [markdown]
# - image shape : (500, 500, 3)

# %%
from keras.preprocessing.image import ImageDataGenerator

# 고막 내시경에 적합한 데이터 증강 방법 적용 -> 수정할 것
train_datagen = ImageDataGenerator(
                                  rotation_range=40,           # 랜덤하게 이미지 회전 각도 설정 (0~40도 사이)
                                  horizontal_flip=True,          # 수평 방향으로 랜덤하게 이미지 뒤집기
                                  vertical_flip=True,            # 수직 방향으로 랜덤하게 이미지 뒤집기
                                  zoom_range=(0.8, 1),           # 랜덤하게 확대/축소 범위 설정, 0.7: 확대, 1: 원본크기와 동일
                                  #shear_range = 0.2,           # 랜덤 전단 변환 범위 설정
                                  #fill_mode = 'nearest',       # 이동으로 인한 빈 픽셀을 가장 가까운 값으로 채우는 방식
                                  brightness_range=[0.7, 1.3],  # 명도 범위
                                  rescale = 1/255.0)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Load images from directories and apply augmentations
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(224, 224),
        batch_size=16,
        class_mode='categorical',
        color_mode='rgb',  # TIFF 파일을 RGB 색상 모드로 로드
        interpolation='nearest')  # 이미지 보간 방법 설정


validation_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(224, 224),
        batch_size=16,
        class_mode='categorical',
        color_mode='rgb',  # TIFF 파일을 RGB 색상 모드로 로드
        interpolation='nearest')  # 이미지 보간 방법 설정

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=16,
        class_mode='categorical',
        color_mode='rgb',  # TIFF 파일을 RGB 색상 모드로 로드
        interpolation='nearest')  # 이미지 보간 방법 설정
# Out:
# Found 482 images belonging to 2 classes.
# Found 106 images belonging to 2 classes.
# Found 106 images belonging to 2 classes.

# %%
class_indices = train_generator.class_indices
# reversing the dictionary
index_class = {v: k for k, v in class_indices.items()}

# %%
index_class
# Out:
# {0: 'Abnormal', 1: 'Normal'}

# %% [markdown]
# - 데이터 증강된 이미지 확인해보기

# %%
# plot the augmented train images
import matplotlib.pyplot as plt

# Set the number of images to plot
num_images = 5

# Get a batch of augmented images and labels from train_data
augmented_images, augmented_labels = next(train_generator)

# Plot the augmented images
fig, axes = plt.subplots(1, num_images, figsize=(12, 6))

for i in range(num_images):
    image = augmented_images[i]
    label = augmented_labels[i]

    axes[i].imshow(image)
    # axes[i].set_title(f'Label: {label}')

    class_cat = index_class[np.argmax(label)]
    axes[i].set_title(f'Class: {class_cat}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Model

# %% [markdown]
# - Xception

# %%
import tensorflow as tf
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.models import Model

xception_model = Xception(weights = 'imagenet',
                          include_top = False,
                          input_shape = (224, 224, 3))

x = GlobalAveragePooling2D()(xception_model.output)
x = Dense(256, activation = 'relu')(x)
x = Dense(2, activation = 'softmax')(x)  # Modify the final Dense layer based on your specific problem

xception = Model(inputs = xception_model.input, outputs = x)

xception.build(input_shape=(None, 224, 224, 3))

# %%
xception.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 111, 111, 32)         864       ['input_3[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 111, 111, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 111, 111, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 109, 109, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 109, 109, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 109, 109, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 109, 109, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 109, 109, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 109, 109, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 109, 109, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 109, 109, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_8 (Conv2D)           (None, 55, 55, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 55, 55, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_8 (Bat  (None, 55, 55, 128)          512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  add_24 (Add)                (None, 55, 55, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization_8[0][0]'
#                                                                     ]
#
#  block3_sepconv1_act (Activ  (None, 55, 55, 128)          0         ['add_24[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 55, 55, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 55, 55, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 55, 55, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 55, 55, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 55, 55, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 256)          32768     ['add_24[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_9 (Bat  (None, 28, 28, 256)          1024      ['conv2d_9[0][0]']
#  chNormalization)
#
#  add_25 (Add)                (None, 28, 28, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_9[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 28, 28, 256)          0         ['add_25[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 28, 28, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 28, 28, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 28, 28, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 28, 28, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 28, 28, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 728)          186368    ['add_25[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_10 (Ba  (None, 14, 14, 728)          2912      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  add_26 (Add)                (None, 14, 14, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_10[0][0]
#                                                                     ']
#
#  block5_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_26[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_27 (Add)                (None, 14, 14, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_26[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_27[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_28 (Add)                (None, 14, 14, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_27[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_28[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_29 (Add)                (None, 14, 14, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_28[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_29[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_30 (Add)                (None, 14, 14, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_29[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_30[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_31 (Add)                (None, 14, 14, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_30[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_31[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_32 (Add)                (None, 14, 14, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_31[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_32[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_33 (Add)                (None, 14, 14, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_32[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_33[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_34 (Add)                (None, 14, 14, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_33[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_34[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 14, 14, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 14, 14, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 1024)           745472    ['add_34[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 7, 7, 1024)           0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_11 (Ba  (None, 7, 7, 1024)           4096      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  add_35 (Add)                (None, 7, 7, 1024)           0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_11[0][0]
#                                                                     ']
#
#  block14_sepconv1 (Separabl  (None, 7, 7, 1536)           1582080   ['add_35[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 7, 7, 1536)           6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 7, 7, 1536)           0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 7, 7, 2048)           3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 7, 7, 2048)           8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 7, 7, 2048)           0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
#  global_average_pooling2d_2  (None, 2048)                 0         ['block14_sepconv2_act[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 256)                  524544    ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_5 (Dense)             (None, 2)                    514       ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 21386538 (81.58 MB)
# Trainable params: 21332010 (81.38 MB)
# Non-trainable params: 54528 (213.00 KB)
# __________________________________________________________________________________________________

# %%
from keras.optimizers import Adam

xception.compile(optimizer = Adam(learning_rate = 0.001), loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# - ReduceLROnPlateau:
#   - 검증 손실(val_loss)이 10번의 에포크(patience)동안 향상되지 않으면 학습률(learning rate)을 0.1배(factor)로 감소시킵니다.
#   - 이는 학습 도중 학습률을 동적으로 조절하여 학습을 안정화시키는 데 사용됩니다.
# - EarlyStopping:
#   - 검증 손실(val_loss)이 20번의 에포크(patience)동안 향상되지 않으면 학습을 조기에 종료합니다.
#   - 이를 통해 과적합을 방지하고 효율적인 학습을 할 수 있습니다.
# - ModelCheckpoint:
#   - 검증 손실(val_loss)이 가장 낮을 때 모델을 저장합니다.
#   - 이를 통해 최상의 성능을 보이는 모델을 저장하여 나중에 재사용할 수 있습니다.

# %%
# 활성 세션 내 모델 저장소 디렉토리 생성
os.makedirs('/content/model/')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-43-51cda6ab9e77> in <cell line: 2>()
#       1 # 활성 세션 내 모델 저장소 디렉토리 생성
# ----> 2 os.makedirs('/content/model/')
#
# /usr/lib/python3.10/os.py in makedirs(name, mode, exist_ok)
#     223             return
#     224     try:
# --> 225         mkdir(name, mode)
#     226     except OSError:
#     227         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: '/content/model/'

# %%
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

# rlr_cb = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1, patience = 10, mode = 'min', verbose = 1)
ely_cb = EarlyStopping(monitor = 'val_loss', patience = 40, mode = 'min', verbose = 1)

# model_path = "/content/drive/MyDrive/eardrum/model/" # 모델 저장 경로(구글 드라이브)
# <- 구글 드라이브 용량 많을 때 사용할 것, 생성된 모델 필요없으면 정리해줄 것
# 그냥 초기에 여러 번 실험할 때는 아래 활성 세션 내 모델 저장소에 저장하고 필요시 수동으로 구글드라이브 모델 경로에 저장하자

model_path = "/content/model/" # 모델 저장 경로(활성 세션 내)
checkpoint_cb = ModelCheckpoint(filepath = model_path+ "xception_model_1.h5", save_best_only = True,
                                monitor = 'val_loss', mode = 'min', verbose = 1) # 모델 이름 수정할 것

#  epochs = 100
history_aug = xception.fit(train_generator, validation_data = validation_generator,
                           epochs = 150, callbacks = [ely_cb, checkpoint_cb])
# Out:
# Epoch 1/150
# 31/31 [==============================] - ETA: 0s - loss: 0.6401 - accuracy: 0.7593
# Epoch 1: val_loss improved from inf to 1.94267, saving model to /content/model/xception_model_1.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 31/31 [==============================] - 39s 540ms/step - loss: 0.6401 - accuracy: 0.7593 - val_loss: 1.9427 - val_accuracy: 0.7642
# Epoch 2/150
# 31/31 [==============================] - ETA: 0s - loss: 0.5614 - accuracy: 0.7718
# Epoch 2: val_loss improved from 1.94267 to 0.80742, saving model to /content/model/xception_model_1.h5
# 31/31 [==============================] - 17s 545ms/step - loss: 0.5614 - accuracy: 0.7718 - val_loss: 0.8074 - val_accuracy: 0.7642
# Epoch 3/150
# 31/31 [==============================] - ETA: 0s - loss: 0.5004 - accuracy: 0.7718
# Epoch 3: val_loss did not improve from 0.80742
# 31/31 [==============================] - 16s 489ms/step - loss: 0.5004 - accuracy: 0.7718 - val_loss: 3.3961 - val_accuracy: 0.7642
# Epoch 4/150
# 31/31 [==============================] - ETA: 0s - loss: 0.4409 - accuracy: 0.7863
# Epoch 4: val_loss did not improve from 0.80742
# 31/31 [==============================] - 15s 496ms/step - loss: 0.4409 - accuracy: 0.7863 - val_loss: 1.4566 - val_accuracy: 0.7642
# Epoch 5/150
# 31/31 [==============================] - ETA: 0s - loss: 0.4608 - accuracy: 0.8071
# Epoch 5: val_loss did not improve from 0.80742
# 31/31 [==============================] - 16s 501ms/step - loss: 0.4608 - accuracy: 0.8071 - val_loss: 0.9549 - val_accuracy: 0.7453
# Epoch 6/150
# 31/31 [==============================] - ETA: 0s - loss: 0.4189 - accuracy: 0.8257
# Epoch 6: val_loss improved from 0.80742 to 0.68811, saving model to /content/model/xception_model_1.h5
# 31/31 [==============================] - 16s 524ms/step - loss: 0.4189 - accuracy: 0.8257 - val_loss: 0.6881 - val_accuracy: 0.7830
# Epoch 7/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3661 - accuracy: 0.8506
# Epoch 7: val_loss improved from 0.68811 to 0.34484, saving model to /content/model/xception_model_1.h5
# 31/31 [==============================] - 16s 524ms/step - loss: 0.3661 - accuracy: 0.8506 - val_loss: 0.3448 - val_accuracy: 0.8491
# Epoch 8/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3523 - accuracy: 0.8444
# Epoch 8: val_loss did not improve from 0.34484
# 31/31 [==============================] - 16s 484ms/step - loss: 0.3523 - accuracy: 0.8444 - val_loss: 2.0768 - val_accuracy: 0.6321
# Epoch 9/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3612 - accuracy: 0.8548
# Epoch 9: val_loss did not improve from 0.34484
# 31/31 [==============================] - 15s 489ms/step - loss: 0.3612 - accuracy: 0.8548 - val_loss: 0.4730 - val_accuracy: 0.7925
# Epoch 10/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3641 - accuracy: 0.8610
# Epoch 10: val_loss did not improve from 0.34484
# 31/31 [==============================] - 15s 487ms/step - loss: 0.3641 - accuracy: 0.8610 - val_loss: 0.5749 - val_accuracy: 0.8491
# Epoch 11/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3606 - accuracy: 0.8485
# Epoch 11: val_loss did not improve from 0.34484
# 31/31 [==============================] - 16s 498ms/step - loss: 0.3606 - accuracy: 0.8485 - val_loss: 0.4406 - val_accuracy: 0.8491
# Epoch 12/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3028 - accuracy: 0.8693
# Epoch 12: val_loss did not improve from 0.34484
# 31/31 [==============================] - 15s 488ms/step - loss: 0.3028 - accuracy: 0.8693 - val_loss: 0.5592 - val_accuracy: 0.8302
# Epoch 13/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3326 - accuracy: 0.8672
# Epoch 13: val_loss did not improve from 0.34484
# 31/31 [==============================] - 15s 506ms/step - loss: 0.3326 - accuracy: 0.8672 - val_loss: 0.3625 - val_accuracy: 0.8585
# Epoch 14/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3220 - accuracy: 0.8755
# Epoch 14: val_loss did not improve from 0.34484
# 31/31 [==============================] - 15s 488ms/step - loss: 0.3220 - accuracy: 0.8755 - val_loss: 0.4491 - val_accuracy: 0.8774
# Epoch 15/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3169 - accuracy: 0.8797
# Epoch 15: val_loss did not improve from 0.34484
# 31/31 [==============================] - 15s 491ms/step - loss: 0.3169 - accuracy: 0.8797 - val_loss: 0.4901 - val_accuracy: 0.7925
# Epoch 16/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3248 - accuracy: 0.8714
# Epoch 16: val_loss did not improve from 0.34484
# 31/31 [==============================] - 15s 484ms/step - loss: 0.3248 - accuracy: 0.8714 - val_loss: 0.7918 - val_accuracy: 0.8019
# Epoch 17/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3004 - accuracy: 0.8714
# Epoch 17: val_loss improved from 0.34484 to 0.30858, saving model to /content/model/xception_model_1.h5
# 31/31 [==============================] - 16s 522ms/step - loss: 0.3004 - accuracy: 0.8714 - val_loss: 0.3086 - val_accuracy: 0.8396
# Epoch 18/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3121 - accuracy: 0.8817
# Epoch 18: val_loss did not improve from 0.30858
# 31/31 [==============================] - 17s 529ms/step - loss: 0.3121 - accuracy: 0.8817 - val_loss: 0.4722 - val_accuracy: 0.8679
# Epoch 19/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2850 - accuracy: 0.8776
# Epoch 19: val_loss did not improve from 0.30858
# 31/31 [==============================] - 16s 512ms/step - loss: 0.2850 - accuracy: 0.8776 - val_loss: 0.4442 - val_accuracy: 0.8302
# Epoch 20/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2654 - accuracy: 0.9025
# Epoch 20: val_loss did not improve from 0.30858
# 31/31 [==============================] - 15s 496ms/step - loss: 0.2654 - accuracy: 0.9025 - val_loss: 0.3513 - val_accuracy: 0.8679
# Epoch 21/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2884 - accuracy: 0.8921
# Epoch 21: val_loss did not improve from 0.30858
# 31/31 [==============================] - 16s 497ms/step - loss: 0.2884 - accuracy: 0.8921 - val_loss: 0.5928 - val_accuracy: 0.7547
# Epoch 22/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.8942
# Epoch 22: val_loss did not improve from 0.30858
# 31/31 [==============================] - 16s 508ms/step - loss: 0.2580 - accuracy: 0.8942 - val_loss: 0.4385 - val_accuracy: 0.8113
# Epoch 23/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2638 - accuracy: 0.8963
# Epoch 23: val_loss did not improve from 0.30858
# 31/31 [==============================] - 16s 510ms/step - loss: 0.2638 - accuracy: 0.8963 - val_loss: 0.4333 - val_accuracy: 0.8679
# Epoch 24/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2543 - accuracy: 0.8983
# Epoch 24: val_loss did not improve from 0.30858
# 31/31 [==============================] - 17s 548ms/step - loss: 0.2543 - accuracy: 0.8983 - val_loss: 0.6743 - val_accuracy: 0.8491
# Epoch 25/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3932 - accuracy: 0.8361
# Epoch 25: val_loss did not improve from 0.30858
# 31/31 [==============================] - 15s 494ms/step - loss: 0.3932 - accuracy: 0.8361 - val_loss: 8.4671 - val_accuracy: 0.7642
# Epoch 26/150
# 31/31 [==============================] - ETA: 0s - loss: 0.4004 - accuracy: 0.8382
# Epoch 26: val_loss did not improve from 0.30858
# 31/31 [==============================] - 15s 494ms/step - loss: 0.4004 - accuracy: 0.8382 - val_loss: 9.9460 - val_accuracy: 0.8208
# Epoch 27/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3703 - accuracy: 0.8589
# Epoch 27: val_loss did not improve from 0.30858
# 31/31 [==============================] - 15s 495ms/step - loss: 0.3703 - accuracy: 0.8589 - val_loss: 5.5660 - val_accuracy: 0.2925
# Epoch 28/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3866 - accuracy: 0.8320
# Epoch 28: val_loss did not improve from 0.30858
# 31/31 [==============================] - 15s 486ms/step - loss: 0.3866 - accuracy: 0.8320 - val_loss: 0.5313 - val_accuracy: 0.8396
# Epoch 29/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3883 - accuracy: 0.8340
# Epoch 29: val_loss did not improve from 0.30858
# 31/31 [==============================] - 15s 493ms/step - loss: 0.3883 - accuracy: 0.8340 - val_loss: 0.9011 - val_accuracy: 0.6604
# Epoch 30/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3508 - accuracy: 0.8714
# Epoch 30: val_loss did not improve from 0.30858
# 31/31 [==============================] - 15s 486ms/step - loss: 0.3508 - accuracy: 0.8714 - val_loss: 0.3192 - val_accuracy: 0.8679
# Epoch 31/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.8465
# Epoch 31: val_loss did not improve from 0.30858
# 31/31 [==============================] - 16s 493ms/step - loss: 0.3759 - accuracy: 0.8465 - val_loss: 0.3210 - val_accuracy: 0.8491
# Epoch 32/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3330 - accuracy: 0.8631
# Epoch 32: val_loss did not improve from 0.30858
# 31/31 [==============================] - 15s 483ms/step - loss: 0.3330 - accuracy: 0.8631 - val_loss: 0.4603 - val_accuracy: 0.8019
# Epoch 33/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3175 - accuracy: 0.8838
# Epoch 33: val_loss did not improve from 0.30858
# 31/31 [==============================] - 15s 489ms/step - loss: 0.3175 - accuracy: 0.8838 - val_loss: 0.3271 - val_accuracy: 0.8679
# Epoch 34/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3300 - accuracy: 0.8506
# Epoch 34: val_loss did not improve from 0.30858
# 31/31 [==============================] - 15s 485ms/step - loss: 0.3300 - accuracy: 0.8506 - val_loss: 0.9427 - val_accuracy: 0.3208
# Epoch 35/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3183 - accuracy: 0.8402
# Epoch 35: val_loss improved from 0.30858 to 0.29600, saving model to /content/model/xception_model_1.h5
# 31/31 [==============================] - 17s 537ms/step - loss: 0.3183 - accuracy: 0.8402 - val_loss: 0.2960 - val_accuracy: 0.8585
# Epoch 36/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2507 - accuracy: 0.8921
# Epoch 36: val_loss did not improve from 0.29600
# 31/31 [==============================] - 15s 477ms/step - loss: 0.2507 - accuracy: 0.8921 - val_loss: 0.3798 - val_accuracy: 0.8208
# Epoch 37/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3062 - accuracy: 0.8797
# Epoch 37: val_loss did not improve from 0.29600
# 31/31 [==============================] - 15s 486ms/step - loss: 0.3062 - accuracy: 0.8797 - val_loss: 0.5319 - val_accuracy: 0.8585
# Epoch 38/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2696 - accuracy: 0.8900
# Epoch 38: val_loss did not improve from 0.29600
# 31/31 [==============================] - 15s 484ms/step - loss: 0.2696 - accuracy: 0.8900 - val_loss: 0.4201 - val_accuracy: 0.8491
# Epoch 39/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.8900
# Epoch 39: val_loss did not improve from 0.29600
# 31/31 [==============================] - 15s 491ms/step - loss: 0.2665 - accuracy: 0.8900 - val_loss: 0.8143 - val_accuracy: 0.7830
# Epoch 40/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2875 - accuracy: 0.8672
# Epoch 40: val_loss did not improve from 0.29600
# 31/31 [==============================] - 15s 488ms/step - loss: 0.2875 - accuracy: 0.8672 - val_loss: 0.4422 - val_accuracy: 0.8491
# Epoch 41/150
# 31/31 [==============================] - ETA: 0s - loss: 0.3273 - accuracy: 0.8631
# Epoch 41: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 501ms/step - loss: 0.3273 - accuracy: 0.8631 - val_loss: 0.3356 - val_accuracy: 0.8868
# Epoch 42/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.9066
# Epoch 42: val_loss did not improve from 0.29600
# 31/31 [==============================] - 17s 542ms/step - loss: 0.2676 - accuracy: 0.9066 - val_loss: 0.3032 - val_accuracy: 0.8585
# Epoch 43/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9170
# Epoch 43: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 505ms/step - loss: 0.1917 - accuracy: 0.9170 - val_loss: 0.4146 - val_accuracy: 0.8585
# Epoch 44/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2808 - accuracy: 0.8838
# Epoch 44: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 501ms/step - loss: 0.2808 - accuracy: 0.8838 - val_loss: 2.3240 - val_accuracy: 0.4528
# Epoch 45/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2372 - accuracy: 0.9087
# Epoch 45: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 509ms/step - loss: 0.2372 - accuracy: 0.9087 - val_loss: 0.4297 - val_accuracy: 0.8396
# Epoch 46/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2268 - accuracy: 0.9149
# Epoch 46: val_loss did not improve from 0.29600
# 31/31 [==============================] - 17s 553ms/step - loss: 0.2268 - accuracy: 0.9149 - val_loss: 0.8412 - val_accuracy: 0.7264
# Epoch 47/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2242 - accuracy: 0.9170
# Epoch 47: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 516ms/step - loss: 0.2242 - accuracy: 0.9170 - val_loss: 0.6724 - val_accuracy: 0.7170
# Epoch 48/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2057 - accuracy: 0.9253
# Epoch 48: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 500ms/step - loss: 0.2057 - accuracy: 0.9253 - val_loss: 0.3272 - val_accuracy: 0.8962
# Epoch 49/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9046
# Epoch 49: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 506ms/step - loss: 0.2347 - accuracy: 0.9046 - val_loss: 0.4092 - val_accuracy: 0.8679
# Epoch 50/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2095 - accuracy: 0.9149
# Epoch 50: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 509ms/step - loss: 0.2095 - accuracy: 0.9149 - val_loss: 0.4968 - val_accuracy: 0.8585
# Epoch 51/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1770 - accuracy: 0.9274
# Epoch 51: val_loss did not improve from 0.29600
# 31/31 [==============================] - 17s 560ms/step - loss: 0.1770 - accuracy: 0.9274 - val_loss: 0.4067 - val_accuracy: 0.8396
# Epoch 52/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1740 - accuracy: 0.9502
# Epoch 52: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 494ms/step - loss: 0.1740 - accuracy: 0.9502 - val_loss: 0.5092 - val_accuracy: 0.8679
# Epoch 53/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1446 - accuracy: 0.9502
# Epoch 53: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 504ms/step - loss: 0.1446 - accuracy: 0.9502 - val_loss: 0.4685 - val_accuracy: 0.8774
# Epoch 54/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1766 - accuracy: 0.9232
# Epoch 54: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 500ms/step - loss: 0.1766 - accuracy: 0.9232 - val_loss: 0.5678 - val_accuracy: 0.8679
# Epoch 55/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.9336
# Epoch 55: val_loss did not improve from 0.29600
# 31/31 [==============================] - 17s 543ms/step - loss: 0.1611 - accuracy: 0.9336 - val_loss: 0.4778 - val_accuracy: 0.8962
# Epoch 56/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9378
# Epoch 56: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 507ms/step - loss: 0.1720 - accuracy: 0.9378 - val_loss: 0.5562 - val_accuracy: 0.8774
# Epoch 57/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1740 - accuracy: 0.9502
# Epoch 57: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 511ms/step - loss: 0.1740 - accuracy: 0.9502 - val_loss: 0.5597 - val_accuracy: 0.8302
# Epoch 58/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1743 - accuracy: 0.9253
# Epoch 58: val_loss did not improve from 0.29600
# 31/31 [==============================] - 17s 554ms/step - loss: 0.1743 - accuracy: 0.9253 - val_loss: 0.3694 - val_accuracy: 0.8585
# Epoch 59/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1761 - accuracy: 0.9232
# Epoch 59: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 517ms/step - loss: 0.1761 - accuracy: 0.9232 - val_loss: 0.4215 - val_accuracy: 0.8396
# Epoch 60/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1552 - accuracy: 0.9544
# Epoch 60: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 507ms/step - loss: 0.1552 - accuracy: 0.9544 - val_loss: 0.5536 - val_accuracy: 0.8679
# Epoch 61/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9502
# Epoch 61: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 504ms/step - loss: 0.1416 - accuracy: 0.9502 - val_loss: 0.5730 - val_accuracy: 0.8491
# Epoch 62/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1807 - accuracy: 0.9419
# Epoch 62: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 508ms/step - loss: 0.1807 - accuracy: 0.9419 - val_loss: 0.4553 - val_accuracy: 0.8396
# Epoch 63/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1837 - accuracy: 0.9191
# Epoch 63: val_loss did not improve from 0.29600
# 31/31 [==============================] - 17s 553ms/step - loss: 0.1837 - accuracy: 0.9191 - val_loss: 0.7609 - val_accuracy: 0.7453
# Epoch 64/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1435 - accuracy: 0.9419
# Epoch 64: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 494ms/step - loss: 0.1435 - accuracy: 0.9419 - val_loss: 0.5707 - val_accuracy: 0.8491
# Epoch 65/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1523 - accuracy: 0.9419
# Epoch 65: val_loss did not improve from 0.29600
# 31/31 [==============================] - 15s 488ms/step - loss: 0.1523 - accuracy: 0.9419 - val_loss: 0.6342 - val_accuracy: 0.8491
# Epoch 66/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9502
# Epoch 66: val_loss did not improve from 0.29600
# 31/31 [==============================] - 15s 485ms/step - loss: 0.1305 - accuracy: 0.9502 - val_loss: 0.5159 - val_accuracy: 0.8585
# Epoch 67/150
# 31/31 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 0.9772
# Epoch 67: val_loss did not improve from 0.29600
# 31/31 [==============================] - 15s 483ms/step - loss: 0.0745 - accuracy: 0.9772 - val_loss: 0.6066 - val_accuracy: 0.8585
# Epoch 68/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1548 - accuracy: 0.9564
# Epoch 68: val_loss did not improve from 0.29600
# 31/31 [==============================] - 15s 490ms/step - loss: 0.1548 - accuracy: 0.9564 - val_loss: 2.1322 - val_accuracy: 0.5660
# Epoch 69/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9544
# Epoch 69: val_loss did not improve from 0.29600
# 31/31 [==============================] - 15s 491ms/step - loss: 0.1060 - accuracy: 0.9544 - val_loss: 0.5585 - val_accuracy: 0.8019
# Epoch 70/150
# 31/31 [==============================] - ETA: 0s - loss: 0.2021 - accuracy: 0.9336
# Epoch 70: val_loss did not improve from 0.29600
# 31/31 [==============================] - 15s 487ms/step - loss: 0.2021 - accuracy: 0.9336 - val_loss: 0.7483 - val_accuracy: 0.8679
# Epoch 71/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1314 - accuracy: 0.9564
# Epoch 71: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 507ms/step - loss: 0.1314 - accuracy: 0.9564 - val_loss: 0.8041 - val_accuracy: 0.8396
# Epoch 72/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.9606
# Epoch 72: val_loss did not improve from 0.29600
# 31/31 [==============================] - 17s 548ms/step - loss: 0.1210 - accuracy: 0.9606 - val_loss: 0.9528 - val_accuracy: 0.8396
# Epoch 73/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9481
# Epoch 73: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 509ms/step - loss: 0.1160 - accuracy: 0.9481 - val_loss: 0.7586 - val_accuracy: 0.8679
# Epoch 74/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1570 - accuracy: 0.9461
# Epoch 74: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 503ms/step - loss: 0.1570 - accuracy: 0.9461 - val_loss: 1.3262 - val_accuracy: 0.8208
# Epoch 75/150
# 31/31 [==============================] - ETA: 0s - loss: 0.1186 - accuracy: 0.9523
# Epoch 75: val_loss did not improve from 0.29600
# 31/31 [==============================] - 16s 513ms/step - loss: 0.1186 - accuracy: 0.9523 - val_loss: 0.9897 - val_accuracy: 0.8585
# Epoch 75: early stopping

# %%
# 30에폭에 30분 소요

# %% [markdown]
# ### ※ 세션 내에 모델 저장했을 경우, 드라이브에 모델 저장하기(선택)

# %%
from tensorflow.keras.models import load_model

# 저장된 모델 불러오기
loaded_model = load_model("/content/model/xception_model_1.h5")

# %%
# 모델 저장

# 새로운 경로 설정
new_model_path = "/content/drive/MyDrive/eardrum/model/"

loaded_model.save(new_model_path + "xception_model_2.h5") # 모델 이름 수정할 것

# %% [markdown]
# # 3. Check Model Performance

# %%
from matplotlib import pyplot as plt

plt.plot(history_aug.history['loss'], 'r', label = 'Train Loss')
plt.plot(history_aug.history['val_loss'], 'b', label = 'Val Loss')
plt.title('XceptionNet, Training and Validation Loss')
plt.legend()

plt.show()

plt.plot(history_aug.history['accuracy'], 'r', label = 'Train Accuracy')
plt.plot(history_aug.history['val_accuracy'], 'b', label = 'Val Accuracy')
plt.title('XceptionNet, Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
test_loss, test_accuracy = xception.evaluate(test_generator)

print("Test Loss: ", test_loss)
print("Test Accuracy: ", test_accuracy)
# Out:
# 7/7 [==============================] - 1s 177ms/step - loss: 0.8937 - accuracy: 0.8208
# Test Loss:  0.8936980366706848
# Test Accuracy:  0.8207547068595886

# %%
index_class
# Out:
# {0: 'Abnormal', 1: 'Normal'}

# %%
y_pred = xception.predict(test_generator)
predicted_classes = np.argmax(y_pred, axis=1)
# Out:
# 7/7 [==============================] - 2s 184ms/step

# %%
true_classes = test_generator.classes

# %%
error_indices = np.where(predicted_classes != true_classes)[0]

# %% [markdown]
# # test data에 대해 잘못 예측한 경우

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# let's say you want to see the first 5 misclassified images
for i in range(5):
    error_index = error_indices[i]

    img_path = test_generator.filepaths[error_index]
    img = image.load_img(img_path, target_size=(224, 224))  # assuming this was your input size

    true_label = index_class[true_classes[error_index]]
    predicted_label = index_class[predicted_classes[error_index]]

    plt.figure()
    plt.imshow(img)
    plt.title(f"True label: {true_label} \n Predicted label: {predicted_label}")
    plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = list(test_generator.class_indices.keys())  # get the labels as a list

# %%
class_labels
# Out:
# ['Abnormal', 'Normal']

# %%
from sklearn.metrics import confusion_matrix, classification_report

conf_matrix = confusion_matrix(true_classes, predicted_classes)

# %%
conf_matrix
# Out:
# array([[10, 15],
#        [33, 48]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # classification_report

# %%
print(classification_report(true_classes, predicted_classes, digits=2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.17      0.08      0.11        25
#            1       0.76      0.88      0.81        81
#
#     accuracy                           0.69       106
#    macro avg       0.46      0.48      0.46       106
# weighted avg       0.62      0.69      0.65       106

# %% [markdown]
# # F1 score
